# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
experiments = [[1,160,5000,'Max',0.062,'Early'],[1,160,5000,'Mean',0.057,'Early'],[1,160,5000,'Min',0.051,'Early'],[1,160,5000,'Val',0.050,'Early']]
experiments.append([1,160,5000,'Train',0.003,'Early'])

# %%
experiments.append([0.5,160,5000,'Max',0.0023,'Early'])
experiments.append([0.5,160,5000,'Min',0.0020,'Early'])
experiments.append([0.5,160,5000,'Mean',0.0021,'Early'])
experiments.append([0.5,160,5000,'Val',0.0025,'Early'])
experiments.append([0.5,160,5000,'Train',3.2e-5,'Early'])

# %%
experiments.append([2,160,5000,'Max',0.28,'Early'])
experiments.append([2,160,5000,'Min',0.25,'Early'])
experiments.append([2,160,5000,'Mean',0.26,'Early'])
experiments.append([2,160,5000,'Val',0.28,'Early'])
experiments.append([2,160,5000,'Train',0.19,'Early'])

# %%
experiments.append([2,1600,5000,'Max',0.25,'Early'])
experiments.append([2,1600,5000,'Min',0.25,'Early'])
experiments.append([2,1600,5000,'Mean',0.25,'Early'])
experiments.append([2,1600,5000,'Val',0.26,'Early'])
experiments.append([2,1600,5000,'Train',0.25,'Early'])

# %%
experiments.append([1,1600,5000,'Max',0.23,'Early'])
experiments.append([1,1600,5000,'Min',0.23,'Early'])
experiments.append([1,1600,5000,'Mean',0.23,'Early'])
experiments.append([1,1600,5000,'Val',0.23,'Early'])
experiments.append([1,1600,5000,'Train',0.23,'Early'])

# %%
experiments.append([0.5,1600,5000,'Max',0.00068,'Early'])
experiments.append([0.5,1600,5000,'Min',0.00067,'Early'])
experiments.append([0.5,1600,5000,'Mean',0.00067,'Early'])
experiments.append([0.5,1600,5000,'Val',0.00066,'Early'])
experiments.append([0.5,1600,5000,'Train',0.00053,'Early'])

# %%
experiments.append([0.5,160,5000,'Max',0.0055,'Early'])
experiments.append([0.5,160,5000,'Min',0.0034,'Early'])
experiments.append([0.5,160,5000,'Mean',0.0045,'Early'])
experiments.append([0.5,160,5000,'Val',0.0042,'Early'])
experiments.append([0.5,160,5000,'Train',0.00018,'Early'])

# %%
experiments.append([1,160,5000,'Max',0.26,'Test'])
experiments.append([1,160,5000,'Min',0.23,'Test'])
experiments.append([1,160,5000,'Mean',0.24,'Test'])
experiments.append([1,160,5000,'Val',0.28,'Test'])
experiments.append([1,160,5000,'Train',0.23,'Test'])

# %%
experiments.append([1,160,5000,'Max',0.12,'Final'])
experiments.append([1,160,5000,'Min',0.10,'Final'])
experiments.append([1,160,5000,'Mean',0.10,'Final'])
experiments.append([1,160,5000,'Val',0.11,'Final'])
experiments.append([1,160,5000,'Train',0.11,'Final'])

# %%
experiments.append([2,6400,500,'Max',0.0055,'Final2'])
experiments.append([2,6400,500,'Min',0.0053,'Final2'])
experiments.append([2,6400,500,'Mean',0.0054,'Final2'])
experiments.append([2,6400,500,'Val',0.0054,'Final2'])
experiments.append([2,6400,500,'Train',0.0043,'Final2'])
experiments.append([2,6400,500,'GenErr',0.0053-0.0043,'Final2'])
experiments.append([2,6400,500,'GenBound',0.0012,'Final2'])
experiments.append([2,6400,500,'TrainTime',42500,'Final2'])

# %%
experiments.append([1.5,6400,500,'Max',0.0027,'Final2'])
experiments.append([1.5,6400,500,'Min',0.0024,'Final2'])
experiments.append([1.5,6400,500,'Mean',0.0026,'Final2'])
experiments.append([1.5,6400,500,'Val',0.0025,'Final2'])
experiments.append([1.5,6400,500,'Train',0.0021,'Final2'])
experiments.append([1.5,6400,500,'GenErr',0.0024-0.0021,'Final2'])
experiments.append([1.5,6400,500,'GenBound',0.00057,'Final2'])
experiments.append([1.5,6400,500,'TrainTime',26668,'Final2'])

# %%
experiments.append([1,6400,500,'Max',0.0017,'Final2'])
experiments.append([1,6400,500,'Min',0.0011,'Final2'])
experiments.append([1,6400,500,'Mean',0.0014,'Final2'])
experiments.append([1,6400,500,'Val',0.0017,'Final2'])
experiments.append([1,6400,500,'Train',0.0011,'Final2'])
experiments.append([1,6400,500,'GenErr',0.0011-0.0011,'Final2'])
experiments.append([1,6400,500,'GenBound',0.00060,'Final2'])
experiments.append([1,6400,500,'TrainTime',12408,'Final2'])

# %%
experiments.append([0.5,6400,500,'Max',0.00014,'Final2'])
experiments.append([0.5,6400,500,'Min',0.00013,'Final2'])
experiments.append([0.5,6400,500,'Mean',0.00013,'Final2'])
experiments.append([0.5,6400,500,'Val',0.00014,'Final2'])
experiments.append([0.5,6400,500,'Train',0.00012,'Final2'])
experiments.append([0.5,6400,500,'GenErr',0.00013-0.00012,'Final2'])
experiments.append([0.5,6400,500,'GenBound',0.000019,'Final2'])
experiments.append([0.5,6400,500,'TrainTime',7219,'Final2'])

# %%
experiments.append([1,640,500,'Max',0.0074,'Final2'])
experiments.append([1,640,500,'Min',0.0065,'Final2'])
experiments.append([1,640,500,'Mean',0.0070,'Final2'])
experiments.append([1,640,500,'Val',0.0068,'Final2'])
experiments.append([1,640,500,'Train',0.0026,'Final2'])
experiments.append([1,640,500,'GenErr',0.0065-0.0026,'Final2'])
experiments.append([1,640,500,'GenBound',0.0048,'Final2'])
experiments.append([1,640,500,'TrainTime',10447,'Final2'])

# %%
experiments.append([0.5,640,500,'Max',0.00023,'Final2'])
experiments.append([0.5,640,500,'Min',0.00015,'Final2'])
experiments.append([0.5,640,500,'Mean',0.00018,'Final2'])
experiments.append([0.5,640,500,'Val',0.00019,'Final2'])
experiments.append([0.5,640,500,'Train',0.000017,'Final2'])
experiments.append([0.5,640,500,'GenErr',0.00015-0.000017,'Final2'])
experiments.append([0.5,640,500,'GenBound',0.00022,'Final2'])
experiments.append([0.5,640,500,'TrainTime',12125,'Final2'])

# %%
experiments.append([1,160,500,'Max',0.27,'Final2'])
experiments.append([1,160,500,'Min',0.20,'Final2'])
experiments.append([1,160,500,'Mean',0.25,'Final2'])
experiments.append([1,160,500,'Val',0.25,'Final2'])
experiments.append([1,160,500,'Train',0.22,'Final2'])
experiments.append([1,160,500,'GenErr',0.22-0.20,'Final2'])
experiments.append([1,160,500,'GenBound',0.057,'Final2'])
experiments.append([1,160,500,'TrainTime',302,'Final2'])

# %%
experiments.append([1,160,500,'Max',0.30,'Final2'])
experiments.append([1,160,500,'Min',0.21,'Final2'])
experiments.append([1,160,500,'Mean',0.24,'Final2'])
experiments.append([1,160,500,'Val',0.24,'Final2'])
experiments.append([1,160,500,'Train',0.21,'Final2'])
experiments.append([1,160,500,'GenErr',0.21-0.21,'Final2'])
experiments.append([1,160,500,'GenBound',0.085,'Final2'])
experiments.append([1,160,500,'TrainTime',302,'Final2'])

# %%
experiments.append([0.5,160,500,'Max',0.0049,'Final2'])
experiments.append([0.5,160,500,'Min',0.0031,'Final2'])
experiments.append([0.5,160,500,'Mean',0.0044,'Final2'])
experiments.append([0.5,160,500,'Val',0.0056,'Final2'])
experiments.append([0.5,160,500,'Train',0.00049,'Final2'])
experiments.append([0.5,160,500,'GenErr',0.0031-0.00049,'Final2'])
experiments.append([0.5,160,500,'GenBound',0.0044,'Final2'])
experiments.append([0.5,160,500,'TrainTime',6494,'Final2'])

# %%
experiments.append([1.5,160,500,'Max',0.27,'Final2'])
experiments.append([1.5,160,500,'Min',0.23,'Final2'])
experiments.append([1.5,160,500,'Mean',0.25,'Final2'])
experiments.append([1.5,160,500,'Val',0.24,'Final2'])
experiments.append([1.5,160,500,'Train',0.21,'Final2'])
experiments.append([1.5,160,500,'GenErr',0.23-0.21,'Final2'])
experiments.append([1.5,160,500,'GenBound',0.057,'Final2'])
experiments.append([1.5,160,500,'TrainTime',302,'Final2'])

# %%
experiments.append([2,160,500,'Max',0.29,'Final2'])
experiments.append([2,160,500,'Min',0.24,'Final2'])
experiments.append([2,160,500,'Mean',0.26,'Final2'])
experiments.append([2,160,500,'Val',0.32,'Final2'])
experiments.append([2,160,500,'Train',0.21,'Final2'])
experiments.append([2,160,500,'GenErr',0.24-0.21,'Final2'])
experiments.append([2,160,500,'GenBound',0.084,'Final2'])
experiments.append([2,160,500,'TrainTime',302,'Final2'])

# %%
experiments.append([2,1600,500,'Max',0.29,'Final2'])
experiments.append([2,1600,500,'Min',0.24,'Final2'])
experiments.append([2,1600,500,'Mean',0.26,'Final2'])
experiments.append([2,1600,500,'Val',0.32,'Final2'])
experiments.append([2,1600,500,'Train',0.21,'Final2'])
experiments.append([2,1600,500,'GenErr',0.24-0.21,'Final2'])
experiments.append([2,1600,500,'GenBound',0.0074,'Final2'])
experiments.append([2,1600,500,'TrainTime',302,'Final2'])

# %%
experiments.append([1.5,1600,500,'Max',0.011,'Final2'])
experiments.append([1.5,1600,500,'Min',0.010,'Final2'])
experiments.append([1.5,1600,500,'Mean',0.010,'Final2'])
experiments.append([1.5,1600,500,'Val',0.010,'Final2'])
experiments.append([1.5,1600,500,'Train',0.0060,'Final2'])
experiments.append([1.5,1600,500,'GenErr',0.10-0.0060,'Final2'])
experiments.append([1.5,1600,500,'GenBound',0.0048,'Final2'])
experiments.append([1.5,1600,500,'TrainTime',22232,'Final2'])

# %%
experiments.append([1.5,1600,500,'Max',0.0042,'Final2'])
experiments.append([1.5,1600,500,'Min',0.0037,'Final2'])
experiments.append([1.5,1600,500,'Mean',0.0040,'Final2'])
experiments.append([1.5,1600,500,'Val',0.0044,'Final2'])
experiments.append([1.5,1600,500,'Train',0.0019,'Final2'])
experiments.append([1.5,1600,500,'GenErr',0.0037-0.0019,'Final2'])
experiments.append([1.5,1600,500,'GenBound',0.0024,'Final2'])
experiments.append([1.5,1600,500,'TrainTime',26023,'Final2'])

# %%
experiments.append([2,1600,500,'Max',0.26,'Final2'])
experiments.append([2,1600,500,'Min',0.23,'Final2'])
experiments.append([2,1600,500,'Mean',0.24,'Final2'])
experiments.append([2,1600,500,'Val',0.24,'Final2'])
experiments.append([2,1600,500,'Train',0.23,'Final2'])
experiments.append([2,1600,500,'GenErr',0.23-0.23,'Final2'])
experiments.append([2,1600,500,'GenBound',0.024,'Final2'])
experiments.append([2,1600,500,'TrainTime',379,'Final2'])

# %%
experiments.append([2,1600,5000,'Max',0.16,'Final2'])
experiments.append([2,1600,5000,'Min',0.16,'Final2'])
experiments.append([2,1600,5000,'Mean',0.16,'Final2'])
experiments.append([2,1600,5000,'Val',0.16,'Final2'])
experiments.append([2,1600,5000,'Train',0.13,'Final2'])
experiments.append([2,1600,5000,'GenErr',0.16-0.13,'Final2'])
experiments.append([2,1600,5000,'GenBound',0.036,'Final2'])
experiments.append([2,1600,5000,'TrainTime',5368,'Final2'])

# %%
experiments.append([1.5,1600,5000,'Max',0.014,'Final2'])
experiments.append([1.5,1600,5000,'Min',0.013,'Final2'])
experiments.append([1.5,1600,5000,'Mean',0.014,'Final2'])
experiments.append([1.5,1600,5000,'Val',0.014,'Final2'])
experiments.append([1.5,1600,5000,'Train',0.009,'Final2'])
experiments.append([1.5,1600,5000,'GenErr',0.013-0.009,'Final2'])
experiments.append([1.5,1600,5000,'GenBound',0.0054,'Final2'])
experiments.append([1.5,1600,5000,'TrainTime',7414,'Final2'])

# %%
experiments.append([1,1600,5000,'Max',0.0054,'Final2'])
experiments.append([1,1600,5000,'Min',0.0045,'Final2'])
experiments.append([1,1600,5000,'Mean',0.0050,'Final2'])
experiments.append([1,1600,5000,'Val',0.0049,'Final2'])
experiments.append([1,1600,5000,'Train',0.0037,'Final2'])
experiments.append([1,1600,5000,'GenErr',0.0045-0.0037,'Final2'])
experiments.append([1,1600,5000,'GenBound',0.0016,'Final2'])
experiments.append([1,1600,5000,'TrainTime',3297,'Final2'])

# %%
experiments.append([0.5,1600,5000,'Max',0.00016,'Final2'])
experiments.append([0.5,1600,5000,'Min',0.00014,'Final2'])
experiments.append([0.5,1600,5000,'Mean',0.00015,'Final2'])
experiments.append([0.5,1600,5000,'Val',0.00015,'Final2'])
experiments.append([0.5,1600,5000,'Train',0.000082,'Final2'])
experiments.append([0.5,1600,5000,'GenErr',0.00014-0.000082,'Final2'])
experiments.append([0.5,1600,5000,'GenBound',0.000077,'Final2'])
experiments.append([0.5,1600,5000,'TrainTime',3194,'Final2'])

# %%
experiments.append([0.5,160,5000,'Max',0.0032,'Final2'])
experiments.append([0.5,160,5000,'Min',0.0022,'Final2'])
experiments.append([0.5,160,5000,'Mean',0.0027,'Final2'])
experiments.append([0.5,160,5000,'Val',0.0021,'Final2'])
experiments.append([0.5,160,5000,'Train',0.000040,'Final2'])
experiments.append([0.5,160,5000,'GenErr',0.0022-0.000040,'Final2'])
experiments.append([0.5,160,5000,'GenBound',0.0032,'Final2'])
experiments.append([0.5,160,5000,'TrainTime',3067,'Final2'])

# %%
experiments.append([1,160,5000,'Max',0.27,'Final2'])
experiments.append([1,160,5000,'Min',0.19,'Final2'])
experiments.append([1,160,5000,'Mean',0.23,'Final2'])
experiments.append([1,160,5000,'Val',0.22,'Final2'])
experiments.append([1,160,5000,'Train',0.17,'Final2'])
experiments.append([1,160,5000,'GenErr',0.19-0.17,'Final2'])
experiments.append([1,160,5000,'GenBound',0.10,'Final2'])
experiments.append([1,160,5000,'TrainTime',302,'Final2'])

# %%
experiments.append([1.5,160,5000,'Max',0.30,'Final2'])
experiments.append([1.5,160,5000,'Min',0.22,'Final2'])
experiments.append([1.5,160,5000,'Mean',0.25,'Final2'])
experiments.append([1.5,160,5000,'Val',0.21,'Final2'])
experiments.append([1.5,160,5000,'Train',0.19,'Final2'])
experiments.append([1.5,160,5000,'GenErr',0.21-0.19,'Final2'])
experiments.append([1.5,160,5000,'GenBound',0.10,'Final2'])
experiments.append([1.5,160,5000,'TrainTime',302,'Final2'])

# %%
experiments.append([2,160,5000,'Max',0.30,'Final2'])
experiments.append([2,160,5000,'Min',0.25,'Final2'])
experiments.append([2,160,5000,'Mean',0.27,'Final2'])
experiments.append([2,160,5000,'Val',0.23,'Final2'])
experiments.append([2,160,5000,'Train',0.14,'Final2'])
experiments.append([2,160,5000,'GenErr',0.23-0.14,'Final2'])
experiments.append([2,160,5000,'GenBound',0.15,'Final2'])
experiments.append([2,160,5000,'TrainTime',302,'Final2'])

# %%
experiments.append([2,6400,5000,'Max',0.037,'Final2'])
experiments.append([2,6400,5000,'Min',0.035,'Final2'])
experiments.append([2,6400,5000,'Mean',0.036,'Final2'])
experiments.append([2,6400,5000,'Val',0.035,'Final2'])
experiments.append([2,6400,5000,'Train',0.031,'Final2'])
experiments.append([2,6400,5000,'GenErr',0.035-0.031,'Final2'])
experiments.append([2,6400,5000,'GenBound',0.0052,'Final2'])
experiments.append([2,6400,5000,'TrainTime',12782,'Final2'])

# %%
experiments.append([1.5,6400,5000,'Max',0.018,'Final2'])
experiments.append([1.5,6400,5000,'Min',0.018,'Final2'])
experiments.append([1.5,6400,5000,'Mean',0.018,'Final2'])
experiments.append([1.5,6400,5000,'Val',0.018,'Final2'])
experiments.append([1.5,6400,5000,'Train',0.017,'Final2'])
experiments.append([1.5,6400,5000,'GenErr',0.018-0.017,'Final2'])
experiments.append([1.5,6400,5000,'GenBound',0.0017,'Final2'])
experiments.append([1.5,6400,5000,'TrainTime',6249,'Final2'])

# %%
experiments.append([1,6400,5000,'Max',0.0050,'Final2'])
experiments.append([1,6400,5000,'Min',0.0047,'Final2'])
experiments.append([1,6400,5000,'Mean',0.0048,'Final2'])
experiments.append([1,6400,5000,'Val',0.0050,'Final2'])
experiments.append([1,6400,5000,'Train',0.0049,'Final2'])
experiments.append([1,6400,5000,'GenErr',0.0049-0.0047,'Final2'])
experiments.append([1,6400,5000,'GenBound',0.00010,'Final2'])
experiments.append([1,6400,5000,'TrainTime',2869,'Final2'])

# %%
experiments.append([0.5,6400,5000,'Max',0.00079,'Final2'])
experiments.append([0.5,6400,5000,'Min',0.00075,'Final2'])
experiments.append([0.5,6400,5000,'Mean',0.00077,'Final2'])
experiments.append([0.5,6400,5000,'Val',0.00078,'Final2'])
experiments.append([0.5,6400,5000,'Train',0.00082,'Final2'])
experiments.append([0.5,6400,5000,'GenErr',0.00082-0.00075,'Final2'])
experiments.append([0.5,6400,5000,'GenBound',0.000033,'Final2'])
experiments.append([0.5,6400,5000,'TrainTime',1147,'Final2'])

# %%
experiments.append([0.5,6400,10000,'Max',0.0013,'Final2'])
experiments.append([0.5,6400,10000,'Min',0.0013,'Final2'])
experiments.append([0.5,6400,10000,'Mean',0.0013,'Final2'])
experiments.append([0.5,6400,10000,'Val',0.0013,'Final2'])
experiments.append([0.5,6400,10000,'Train',0.0012,'Final2'])
experiments.append([0.5,6400,10000,'GenErr',0.0013-0.0012,'Final2'])
experiments.append([0.5,6400,10000,'GenBound',0.00020,'Final2'])
experiments.append([0.5,6400,10000,'TrainTime',862,'Final2'])

# %%
experiments.append([1,6400,10000,'Max',0.0095,'Final2'])
experiments.append([1,6400,10000,'Min',0.0094,'Final2'])
experiments.append([1,6400,10000,'Mean',0.0094,'Final2'])
experiments.append([1,6400,10000,'Val',0.0093,'Final2'])
experiments.append([1,6400,10000,'Train',0.0089,'Final2'])
experiments.append([1,6400,10000,'GenErr',0.0093-0.0089,'Final2'])
experiments.append([1,6400,10000,'GenBound',0.00060,'Final2'])
experiments.append([1,6400,10000,'TrainTime',1890,'Final2'])

# %%
experiments.append([1.5,6400,10000,'Max',0.058,'Final2'])
experiments.append([1.5,6400,10000,'Min',0.054,'Final2'])
experiments.append([1.5,6400,10000,'Mean',0.056,'Final2'])
experiments.append([1.5,6400,10000,'Val',0.054,'Final2'])
experiments.append([1.5,6400,10000,'Train',0.052,'Final2'])
experiments.append([1.5,6400,10000,'GenErr',0.054-0.052,'Final2'])
experiments.append([1.5,6400,10000,'GenBound',0.0063,'Final2'])
experiments.append([1.5,6400,10000,'TrainTime',3484,'Final2'])

# %%
experiments.append([2,6400,10000,'Max',0.13,'Final2'])
experiments.append([2,6400,10000,'Min',0.12,'Final2'])
experiments.append([2,6400,10000,'Mean',0.12,'Final2'])
experiments.append([2,6400,10000,'Val',0.13,'Final2'])
experiments.append([2,6400,10000,'Train',0.12,'Final2'])
experiments.append([2,6400,10000,'GenErr',0.12-0.12,'Final2'])
experiments.append([2,6400,10000,'GenBound',0.012,'Final2'])
experiments.append([2,6400,10000,'TrainTime',4760,'Final2'])

# %%
experiments.append([2,1600,10000,'Max',0.13,'Final2'])
experiments.append([2,1600,10000,'Min',0.12,'Final2'])
experiments.append([2,1600,10000,'Mean',0.13,'Final2'])
experiments.append([2,1600,10000,'Val',0.13,'Final2'])
experiments.append([2,1600,10000,'Train',0.088,'Final2'])
experiments.append([2,1600,10000,'GenErr',0.12-0.088,'Final2'])
experiments.append([2,1600,10000,'GenBound',0.042,'Final2'])
experiments.append([2,1600,10000,'TrainTime',5787,'Final2'])

# %%
experiments.append([1.5,1600,10000,'Max',0.056,'Final2'])
experiments.append([1.5,1600,10000,'Min',0.050,'Final2'])
experiments.append([1.5,1600,10000,'Mean',0.053,'Final2'])
experiments.append([1.5,1600,10000,'Val',0.053,'Final2'])
experiments.append([1.5,1600,10000,'Train',0.038,'Final2'])
experiments.append([1.5,1600,10000,'GenErr',0.050-0.038,'Final2'])
experiments.append([1.5,1600,10000,'GenBound',0.017,'Final2'])
experiments.append([1.5,1600,10000,'TrainTime',3903,'Final2'])

# %%
experiments.append([1,1600,10000,'Max',0.012,'Final2'])
experiments.append([1,1600,10000,'Min',0.010,'Final2'])
experiments.append([1,1600,10000,'Mean',0.012,'Final2'])
experiments.append([1,1600,10000,'Val',0.011,'Final2'])
experiments.append([1,1600,10000,'Train',0.0098,'Final2'])
experiments.append([1,1600,10000,'GenErr',0.010-0.0098,'Final2'])
experiments.append([1,1600,10000,'GenBound',0.0023,'Final2'])
experiments.append([1,1600,10000,'TrainTime',1953,'Final2'])

# %%
experiments.append([0.5,1600,10000,'Max',0.0017,'Final2'])
experiments.append([0.5,1600,10000,'Min',0.0016,'Final2'])
experiments.append([0.5,1600,10000,'Mean',0.0017,'Final2'])
experiments.append([0.5,1600,10000,'Val',0.0017,'Final2'])
experiments.append([0.5,1600,10000,'Train',0.0012,'Final2'])
experiments.append([0.5,1600,10000,'GenErr',0.0016-0.0012,'Final2'])
experiments.append([0.5,1600,10000,'GenBound',0.00055,'Final2'])
experiments.append([0.5,1600,10000,'TrainTime',934,'Final2'])

# %%
experiments.append([0.5,160,10000,'Max',0.014,'Final2'])
experiments.append([0.5,160,10000,'Min',0.0068,'Final2'])
experiments.append([0.5,160,10000,'Mean',0.011,'Final2'])
experiments.append([0.5,160,10000,'Val',0.0076,'Final2'])
experiments.append([0.5,160,10000,'Train',0.00024,'Final2'])
experiments.append([0.5,160,10000,'GenErr',0.0068-0.00024,'Final2'])
experiments.append([0.5,160,10000,'GenBound',0.014,'Final2'])
experiments.append([0.5,160,10000,'TrainTime',1234,'Final2'])

# %%
experiments.append([1,160,10000,'Max',0.064,'Final2'])
experiments.append([1,160,10000,'Min',0.036,'Final2'])
experiments.append([1,160,10000,'Mean',0.046,'Final2'])
experiments.append([1,160,10000,'Val',0.047,'Final2'])
experiments.append([1,160,10000,'Train',0.0032,'Final2'])
experiments.append([1,160,10000,'GenErr',0.036-0.0032,'Final2'])
experiments.append([1,160,10000,'GenBound',0.061,'Final2'])
experiments.append([1,160,10000,'TrainTime',2222,'Final2'])

# %%
experiments.append([1.5,160,10000,'Max',0.31,'Final2'])
experiments.append([1.5,160,10000,'Min',0.25,'Final2'])
experiments.append([1.5,160,10000,'Mean',0.28,'Final2'])
experiments.append([1.5,160,10000,'Val',0.30,'Final2'])
experiments.append([1.5,160,10000,'Train',0.20,'Final2'])
experiments.append([1.5,160,10000,'GenErr',0.025-0.20,'Final2'])
experiments.append([1.5,160,10000,'GenBound',0.11,'Final2'])
experiments.append([1.5,160,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([2,160,10000,'Max',0.30,'Final2'])
experiments.append([2,160,10000,'Min',0.24,'Final2'])
experiments.append([2,160,10000,'Mean',0.27,'Final2'])
experiments.append([2,160,10000,'Val',0.29,'Final2'])
experiments.append([2,160,10000,'Train',0.21,'Final2'])
experiments.append([2,160,10000,'GenErr',0.24-0.21,'Final2'])
experiments.append([2,160,10000,'GenBound',0.087,'Final2'])
experiments.append([2,160,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([2,160,20000,'Max',0.33,'Final2'])
experiments.append([2,160,20000,'Min',0.24,'Final2'])
experiments.append([2,160,20000,'Mean',0.28,'Final2'])
experiments.append([2,160,20000,'Val',0.25,'Final2'])
experiments.append([2,160,20000,'Train',0.14,'Final2'])
experiments.append([2,160,20000,'GenErr',0.24-0.14,'Final2'])
experiments.append([2,160,20000,'GenBound',0.19,'Final2'])
experiments.append([2,160,20000,'TrainTime',302,'Final2'])

# %%
experiments.append([1.5,160,20000,'Max',0.30,'Final2'])
experiments.append([1.5,160,20000,'Min',0.25,'Final2'])
experiments.append([1.5,160,20000,'Mean',0.28,'Final2'])
experiments.append([1.5,160,20000,'Val',0.24,'Final2'])
experiments.append([1.5,160,20000,'Train',0.16,'Final2'])
experiments.append([1.5,160,20000,'GenErr',0.24-0.16,'Final2'])
experiments.append([1.5,160,20000,'GenBound',0.14,'Final2'])
experiments.append([1.5,160,20000,'TrainTime',302,'Final2'])

# %%
experiments.append([1,160,20000,'Max',0.090,'Final2'])
experiments.append([1,160,20000,'Min',0.061,'Final2'])
experiments.append([1,160,20000,'Mean',0.077,'Final2'])
experiments.append([1,160,20000,'Val',0.080,'Final2'])
experiments.append([1,160,20000,'Train',0.010,'Final2'])
experiments.append([1,160,20000,'GenErr',0.061-0.010,'Final2'])
experiments.append([1,160,20000,'GenBound',0.080,'Final2'])
experiments.append([1,160,20000,'TrainTime',1531,'Final2'])

# %%
experiments.append([0.5,160,20000,'Max',0.0098,'Final2'])
experiments.append([0.5,160,20000,'Min',0.0059,'Final2'])
experiments.append([0.5,160,20000,'Mean',0.0081,'Final2'])
experiments.append([0.5,160,20000,'Val',0.0085,'Final2'])
experiments.append([0.5,160,20000,'Train',0.0061,'Final2'])
experiments.append([0.5,160,20000,'GenErr',0.0061-0.0059,'Final2'])
experiments.append([0.5,160,20000,'GenBound',0.0037,'Final2'])
experiments.append([0.5,160,20000,'TrainTime',1248,'Final2'])

# %%
experiments.append([0.5,1600,20000,'Max',0.00069,'Final2'])
experiments.append([0.5,1600,20000,'Min',0.00067,'Final2'])
experiments.append([0.5,1600,20000,'Mean',0.00068,'Final2'])
experiments.append([0.5,1600,20000,'Val',0.00068,'Final2'])
experiments.append([0.5,1600,20000,'Train',0.00037,'Final2'])
experiments.append([0.5,1600,20000,'GenErr',0.00067-0.00037,'Final2'])
experiments.append([0.5,1600,20000,'GenBound',0.00032,'Final2'])
experiments.append([0.5,1600,20000,'TrainTime',1205,'Final2'])

# %%
experiments.append([1,1600,20000,'Max',0.014,'Final2'])
experiments.append([1,1600,20000,'Min',0.013,'Final2'])
experiments.append([1,1600,20000,'Mean',0.014,'Final2'])
experiments.append([1,1600,20000,'Val',0.013,'Final2'])
experiments.append([1,1600,20000,'Train',0.010,'Final2'])
experiments.append([1,1600,20000,'GenErr',0.013-0.010,'Final2'])
experiments.append([1,1600,20000,'GenBound',0.0038,'Final2'])
experiments.append([1,1600,20000,'TrainTime',1645,'Final2'])

# %%
experiments.append([1.5,1600,20000,'Max',0.087,'Final2'])
experiments.append([1.5,1600,20000,'Min',0.082,'Final2'])
experiments.append([1.5,1600,20000,'Mean',0.084,'Final2'])
experiments.append([1.5,1600,20000,'Val',0.085,'Final2'])
experiments.append([1.5,1600,20000,'Train',0.075,'Final2'])
experiments.append([1.5,1600,20000,'GenErr',0.082-0.075,'Final2'])
experiments.append([1.5,1600,20000,'GenBound',0.012,'Final2'])
experiments.append([1.5,1600,20000,'TrainTime',2269,'Final2'])

# %%
experiments.append([2,1600,20000,'Max',0.21,'Final2'])
experiments.append([2,1600,20000,'Min',0.19,'Final2'])
experiments.append([2,1600,20000,'Mean',0.20,'Final2'])
experiments.append([2,1600,20000,'Val',0.20,'Final2'])
experiments.append([2,1600,20000,'Train',0.17,'Final2'])
experiments.append([2,1600,20000,'GenErr',0.019-0.17,'Final2'])
experiments.append([2,1600,20000,'GenBound',0.015,'Final2'])
experiments.append([2,1600,20000,'TrainTime',1813,'Final2'])

# %%
experiments.append([2,6400,20000,'Max',0.20,'Final2'])
experiments.append([2,6400,20000,'Min',0.19,'Final2'])
experiments.append([2,6400,20000,'Mean',0.20,'Final2'])
experiments.append([2,6400,20000,'Val',0.20,'Final2'])
experiments.append([2,6400,20000,'Train',0.18,'Final2'])
experiments.append([2,6400,20000,'GenErr',0.19-0.18,'Final2'])
experiments.append([2,6400,20000,'GenBound',0.042,'Final2'])
experiments.append([2,6400,20000,'TrainTime',1877,'Final2'])

# %%
experiments.append([1.5,6400,20000,'Max',0.090,'Final2'])
experiments.append([1.5,6400,20000,'Min',0.087,'Final2'])
experiments.append([1.5,6400,20000,'Mean',0.089,'Final2'])
experiments.append([1.5,6400,20000,'Val',0.088,'Final2'])
experiments.append([1.5,6400,20000,'Train',0.084,'Final2'])
experiments.append([1.5,6400,20000,'GenErr',0.087-0.084,'Final2'])
experiments.append([1.5,6400,20000,'GenBound',0.0053,'Final2'])
experiments.append([1.5,6400,20000,'TrainTime',2187,'Final2'])

# %%
experiments.append([1,6400,20000,'Max',0.011,'Final2'])
experiments.append([1,6400,20000,'Min',0.010,'Final2'])
experiments.append([1,6400,20000,'Mean',0.010,'Final2'])
experiments.append([1,6400,20000,'Val',0.010,'Final2'])
experiments.append([1,6400,20000,'Train',0.0095,'Final2'])
experiments.append([1,6400,20000,'GenErr',0.010-0.0095,'Final2'])
experiments.append([1,6400,20000,'GenBound',0.0014,'Final2'])
experiments.append([1,6400,20000,'TrainTime',1782,'Final2'])

# %%
experiments.append([0.5,6400,20000,'Max',0.00057,'Final2'])
experiments.append([0.5,6400,20000,'Min',0.00055,'Final2'])
experiments.append([0.5,6400,20000,'Mean',0.00056,'Final2'])
experiments.append([0.5,6400,20000,'Val',0.00056,'Final2'])
experiments.append([0.5,6400,20000,'Train',0.00033,'Final2'])
experiments.append([0.5,6400,20000,'GenErr',0.00055-0.00033,'Final2'])
experiments.append([0.5,6400,20000,'GenBound',0.00024,'Final2'])
experiments.append([0.5,6400,20000,'TrainTime',1192,'Final2'])

# %%
experiments.append([0.5,6400,100,'Max',0.00022,'Final2'])
experiments.append([0.5,6400,100,'Min',0.00021,'Final2'])
experiments.append([0.5,6400,100,'Mean',0.00022,'Final2'])
experiments.append([0.5,6400,100,'Val',0.00022,'Final2'])
experiments.append([0.5,6400,100,'Train',0.00019,'Final2'])
experiments.append([0.5,6400,100,'GenErr',0.00021-0.00019,'Final2'])
experiments.append([0.5,6400,100,'GenBound',0.000032,'Final2'])
experiments.append([0.5,6400,100,'TrainTime',21737,'Final2'])

# %%
experiments.append([1,6400,100,'Max',0.0026,'Final2'])
experiments.append([1,6400,100,'Min',0.0024,'Final2'])
experiments.append([1,6400,100,'Mean',0.0025,'Final2'])
experiments.append([1,6400,100,'Val',0.0023,'Final2'])
experiments.append([1,6400,100,'Train',0.0023,'Final2'])
experiments.append([1,6400,100,'GenErr',0.0023-0.0023,'Final2'])
experiments.append([1,6400,100,'GenBound',0.00027,'Final2'])
experiments.append([1,6400,100,'TrainTime',28012,'Final2'])

# %%
experiments.append([1.5,6400,100,'Max',0.25,'Final2'])
experiments.append([1.5,6400,100,'Min',0.23,'Final2'])
experiments.append([1.5,6400,100,'Mean',0.24,'Final2'])
experiments.append([1.5,6400,100,'Val',0.23,'Final2'])
experiments.append([1.5,6400,100,'Train',0.24,'Final2'])
experiments.append([1.5,6400,100,'GenErr',0.24-0.23,'Final2'])
experiments.append([1.5,6400,100,'GenBound',0.0034,'Final2'])
experiments.append([1.5,6400,100,'TrainTime',302,'Final2'])

# %%
experiments.append([2,1600,100,'Max',0.26,'Final2'])
experiments.append([2,1600,100,'Min',0.24,'Final2'])
experiments.append([2,1600,100,'Mean',0.25,'Final2'])
experiments.append([2,1600,100,'Val',0.25,'Final2'])
experiments.append([2,1600,100,'Train',0.24,'Final2'])
experiments.append([2,1600,100,'GenErr',0.24-0.24,'Final2'])
experiments.append([2,1600,100,'GenBound',0.020,'Final2'])
experiments.append([2,1600,100,'TrainTime',500,'Final2'])

# %%
experiments.append([0.5,1600,100,'Max',0.00041,'Final2'])
experiments.append([0.5,1600,100,'Min',0.00035,'Final2'])
experiments.append([0.5,1600,100,'Mean',0.00037,'Final2'])
experiments.append([0.5,1600,100,'Val',0.00037,'Final2'])
experiments.append([0.5,1600,100,'Train',0.00020,'Final2'])
experiments.append([0.5,1600,100,'GenErr',0.00035-0.00020,'Final2'])
experiments.append([0.5,1600,100,'GenBound',0.00021,'Final2'])
experiments.append([0.5,1600,100,'TrainTime',17435,'Final2'])

# %%
experiments.append([0.5,160,100,'Max',0.0056,'Final2'])
experiments.append([0.5,160,100,'Min',0.0032,'Final2'])
experiments.append([0.5,160,100,'Mean',0.0043,'Final2'])
experiments.append([0.5,160,100,'Val',0.0040,'Final2'])
experiments.append([0.5,160,100,'Train',0.0011,'Final2'])
experiments.append([0.5,160,100,'GenErr',0.0032-0.0011,'Final2'])
experiments.append([0.5,160,100,'GenBound',0.0045,'Final2'])
experiments.append([0.5,160,100,'TrainTime',15195,'Final2'])

# %%
experiments.append([1,160,100,'Max',0.25,'Final2'])
experiments.append([1,160,100,'Min',0.23,'Final2'])
experiments.append([1,160,100,'Mean',0.22,'Final2'])
experiments.append([1,160,100,'Val',0.20,'Final2'])
experiments.append([1,160,100,'Train',0.18,'Final2'])
experiments.append([1,160,100,'GenErr',0.20-0.18,'Final2'])
experiments.append([1,160,100,'GenBound',0.068,'Final2'])
experiments.append([1,160,100,'TrainTime',4720,'Final2'])

# %%
experiments.append([1.5,160,100,'Max',0.29,'Final2'])
experiments.append([1.5,160,100,'Min',0.23,'Final2'])
experiments.append([1.5,160,100,'Mean',0.25,'Final2'])
experiments.append([1.5,160,100,'Val',0.25,'Final2'])
experiments.append([1.5,160,100,'Train',0.19,'Final2'])
experiments.append([1.5,160,100,'GenErr',0.23-0.19,'Final2'])
experiments.append([1.5,160,100,'GenBound',0.098,'Final2'])
experiments.append([1.5,160,100,'TrainTime',1438,'Final2'])

# %%
experiments.append([2,160,100,'Max',0.35,'Final2'])
experiments.append([2,160,100,'Min',0.25,'Final2'])
experiments.append([2,160,100,'Mean',0.29,'Final2'])
experiments.append([2,160,100,'Val',0.24,'Final2'])
experiments.append([2,160,100,'Train',0.23,'Final2'])
experiments.append([2,160,100,'GenErr',0.24-0.23,'Final2'])
experiments.append([2,160,100,'GenBound',0.12,'Final2'])
experiments.append([2,160,100,'TrainTime',1924,'Final2'])

# %%
experiments.append([2,640,100,'Max',0.27,'Final2'])
experiments.append([2,640,100,'Min',0.25,'Final2'])
experiments.append([2,640,100,'Mean',0.26,'Final2'])
experiments.append([2,640,100,'Val',0.25,'Final2'])
experiments.append([2,640,100,'Train',0.24,'Final2'])
experiments.append([2,640,100,'GenErr',0.25-0.24,'Final2'])
experiments.append([2,640,100,'GenBound',0.029,'Final2'])
experiments.append([2,640,100,'TrainTime',302,'Final2'])

# %%
experiments.append([2,6400,100,'Max',0.25,'Final2'])
experiments.append([2,6400,100,'Min',0.24,'Final2'])
experiments.append([2,6400,100,'Mean',0.25,'Final2'])
experiments.append([2,6400,100,'Val',0.25,'Final2'])
experiments.append([2,6400,100,'Train',0.24,'Final2'])
experiments.append([2,6400,100,'GenErr',0.24-0.24,'Final2'])
experiments.append([2,6400,100,'GenBound',0.0083,'Final2'])
experiments.append([2,6400,100,'TrainTime',477,'Final2'])

# %%
experiments.append([2,1600,200,'Max',0.26,'Final2'])
experiments.append([2,1600,200,'Min',0.24,'Final2'])
experiments.append([2,1600,200,'Mean',0.25,'Final2'])
experiments.append([2,1600,200,'Val',0.24,'Final2'])
experiments.append([2,1600,200,'Train',0.23,'Final2'])
experiments.append([2,1600,200,'GenErr',0.24-0.23,'Final2'])
experiments.append([2,1600,200,'GenBound',0.029,'Final2'])
experiments.append([2,1600,200,'TrainTime',2868,'Final2'])

# %%
experiments.append([0.5,1600,200,'Max',0.00023,'Final2'])
experiments.append([0.5,1600,200,'Min',0.00018,'Final2'])
experiments.append([0.5,1600,200,'Mean',0.00021,'Final2'])
experiments.append([0.5,1600,200,'Val',0.00021,'Final2'])
experiments.append([0.5,1600,200,'Train',0.00012,'Final2'])
experiments.append([0.5,1600,200,'GenErr',0.00018-0.00012,'Final2'])
experiments.append([0.5,1600,200,'GenBound',0.00012,'Final2'])
experiments.append([0.5,1600,200,'TrainTime',12113,'Final2'])

# %%
experiments.append([1,1600,200,'Max',0.0027,'Final2'])
experiments.append([1,1600,200,'Min',0.0016,'Final2'])
experiments.append([1,1600,200,'Mean',0.0021,'Final2'])
experiments.append([1,1600,200,'Val',0.0030,'Final2'])
experiments.append([1,1600,200,'Train',0.0014,'Final2'])
experiments.append([1,1600,200,'GenErr',0.0016-0.0014,'Final2'])
experiments.append([1,1600,200,'GenBound',0.0013,'Final2'])
experiments.append([1,1600,200,'TrainTime',20745,'Final2'])

# %%
experiments.append([1.5,1600,200,'Max',0.24,'Final2'])
experiments.append([1.5,1600,200,'Min',0.23,'Final2'])
experiments.append([1.5,1600,200,'Mean',0.24,'Final2'])
experiments.append([1.5,1600,200,'Val',0.24,'Final2'])
experiments.append([1.5,1600,200,'Train',0.23,'Final2'])
experiments.append([1.5,1600,200,'GenErr',0.23-0.23,'Final2'])
experiments.append([1.5,1600,200,'GenBound',0.012,'Final2'])
experiments.append([1.5,1600,200,'TrainTime',521,'Final2'])

# %%
experiments.append([2,6400,200,'Max',0.072,'Final2'])
experiments.append([2,6400,200,'Min',0.069,'Final2'])
experiments.append([2,6400,200,'Mean',0.070,'Final2'])
experiments.append([2,6400,200,'Val',0.070,'Final2'])
experiments.append([2,6400,200,'Train',0.063,'Final2'])
experiments.append([2,6400,200,'GenErr',0.069-0.063,'Final2'])
experiments.append([2,6400,200,'GenBound',0.0096,'Final2'])
experiments.append([2,6400,200,'TrainTime',50000,'Final2'])

# %%
experiments.append([1.5,6400,200,'Max',0.0058,'Final2'])
experiments.append([1.5,6400,200,'Min',0.0052,'Final2'])
experiments.append([1.5,6400,200,'Mean',0.0055,'Final2'])
experiments.append([1.5,6400,200,'Val',0.0054,'Final2'])
experiments.append([1.5,6400,200,'Train',0.0047,'Final2'])
experiments.append([1.5,6400,200,'GenErr',0.0052-0.0047,'Final2'])
experiments.append([1.5,6400,200,'GenBound',0.0011,'Final2'])
experiments.append([1.5,6400,200,'TrainTime',50000,'Final2'])

# %%
experiments.append([1,6400,200,'Max',0.0016,'Final2'])
experiments.append([1,6400,200,'Min',0.0014,'Final2'])
experiments.append([1,6400,200,'Mean',0.0014,'Final2'])
experiments.append([1,6400,200,'Val',0.0012,'Final2'])
experiments.append([1,6400,200,'Train',0.0012,'Final2'])
experiments.append([1,6400,200,'GenErr',0.0012-0.0012,'Final2'])
experiments.append([1,6400,200,'GenBound',0.00040,'Final2'])
experiments.append([1,6400,200,'TrainTime',22061,'Final2'])

# %%
experiments.append([0.5,6400,200,'Max',0.00012,'Final2'])
experiments.append([0.5,6400,200,'Min',0.00011,'Final2'])
experiments.append([0.5,6400,200,'Mean',0.00011,'Final2'])
experiments.append([0.5,6400,200,'Val',0.00012,'Final2'])
experiments.append([0.5,6400,200,'Train',0.000092,'Final2'])
experiments.append([0.5,6400,200,'GenErr',0.00011-0.000092,'Final2'])
experiments.append([0.5,6400,200,'GenBound',0.000024,'Final2'])
experiments.append([0.5,6400,200,'TrainTime',22061,'Final2'])

# %%
experiments.append([0.5,1600,200,'Max',0.00013,'Final2'])
experiments.append([0.5,1600,200,'Min',0.00011,'Final2'])
experiments.append([0.5,1600,200,'Mean',0.00012,'Final2'])
experiments.append([0.5,1600,200,'Val',0.00013,'Final2'])
experiments.append([0.5,1600,200,'Train',0.000056,'Final2'])
experiments.append([0.5,1600,200,'GenErr',0.00011-0.000056,'Final2'])
experiments.append([0.5,1600,200,'GenBound',0.000069,'Final2'])
experiments.append([0.5,1600,200,'TrainTime',15678,'Final2'])

# %%
experiments.append([1,1600,200,'Max',0.0033,'Final2'])
experiments.append([1,1600,200,'Min',0.0022,'Final2'])
experiments.append([1,1600,200,'Mean',0.0026,'Final2'])
experiments.append([1,1600,200,'Val',0.0026,'Final2'])
experiments.append([1,1600,200,'Train',0.0022,'Final2'])
experiments.append([1,1600,200,'GenErr',0.0022-0.0022,'Final2'])
experiments.append([1,1600,200,'GenBound',0.0011,'Final2'])
experiments.append([1,1600,200,'TrainTime',20004,'Final2'])

# %%
experiments.append([1.5,1600,200,'Max',0.014,'Final2'])
experiments.append([1.5,1600,200,'Min',0.012,'Final2'])
experiments.append([1.5,1600,200,'Mean',0.013,'Final2'])
experiments.append([1.5,1600,200,'Val',0.013,'Final2'])
experiments.append([1.5,1600,200,'Train',0.0075,'Final2'])
experiments.append([1.5,1600,200,'GenErr',0.012-0.0075,'Final2'])
experiments.append([1.5,1600,200,'GenBound',0.0066,'Final2'])
experiments.append([1.5,1600,200,'TrainTime',33741,'Final2'])

# %%
experiments.append([2,1600,200,'Max',0.25,'Final2'])
experiments.append([2,1600,200,'Min',0.24,'Final2'])
experiments.append([2,1600,200,'Mean',0.25,'Final2'])
experiments.append([2,1600,200,'Val',0.24,'Final2'])
experiments.append([2,1600,200,'Train',0.26,'Final2'])
experiments.append([2,1600,200,'GenErr',0.26-0.24,'Final2'])
experiments.append([2,1600,200,'GenBound',0.0053,'Final2'])
experiments.append([2,1600,200,'TrainTime',460,'Final2'])

# %%
experiments.append([2,160,200,'Max',0.29,'Final2'])
experiments.append([2,160,200,'Min',0.26,'Final2'])
experiments.append([2,160,200,'Mean',0.27,'Final2'])
experiments.append([2,160,200,'Val',0.23,'Final2'])
experiments.append([2,160,200,'Train',0.21,'Final2'])
experiments.append([2,160,200,'GenErr',0.23-0.21,'Final2'])
experiments.append([2,160,200,'GenBound',0.085,'Final2'])
experiments.append([2,160,200,'TrainTime',302,'Final2'])

# %%
experiments.append([1.5,160,200,'Max',0.27,'Final2'])
experiments.append([1.5,160,200,'Min',0.25,'Final2'])
experiments.append([1.5,160,200,'Mean',0.26,'Final2'])
experiments.append([1.5,160,200,'Val',0.26,'Final2'])
experiments.append([1.5,160,200,'Train',0.21,'Final2'])
experiments.append([1.5,160,200,'GenErr',0.25-0.21,'Final2'])
experiments.append([1.5,160,200,'GenBound',0.059,'Final2'])
experiments.append([1.5,160,200,'TrainTime',1251,'Final2'])

# %%
experiments.append([1,160,200,'Max',0.25,'Final2'])
experiments.append([1,160,200,'Min',0.20,'Final2'])
experiments.append([1,160,200,'Mean',0.23,'Final2'])
experiments.append([1,160,200,'Val',0.20,'Final2'])
experiments.append([1,160,200,'Train',0.24,'Final2'])
experiments.append([1,160,200,'GenErr',0.24-0.20,'Final2'])
experiments.append([1,160,200,'GenBound',0.0068,'Final2'])
experiments.append([1,160,200,'TrainTime',302,'Final2'])

# %%
experiments.append([0.5,160,200,'Max',0.014,'Final2'])
experiments.append([0.5,160,200,'Min',0.0089,'Final2'])
experiments.append([0.5,160,200,'Mean',0.012,'Final2'])
experiments.append([0.5,160,200,'Val',0.0055,'Final2'])
experiments.append([0.5,160,200,'Train',0.00058,'Final2'])
experiments.append([0.5,160,200,'GenErr',0.0055-0.00058,'Final2'])
experiments.append([0.5,160,200,'GenBound',0.013,'Final2'])
experiments.append([0.5,160,200,'TrainTime',13657,'Final2'])

# %%
experiments.append([0.5,160,50,'Max',0.052,'Final2'])
experiments.append([0.5,160,50,'Min',0.033,'Final2'])
experiments.append([0.5,160,50,'Mean',0.041,'Final2'])
experiments.append([0.5,160,50,'Val',0.036,'Final2'])
experiments.append([0.5,160,50,'Train',0.015,'Final2'])
experiments.append([0.5,160,50,'GenErr',0.033-0.015,'Final2'])
experiments.append([0.5,160,50,'GenBound',0.037,'Final2'])
experiments.append([0.5,160,50,'TrainTime',10451,'Final2'])

# %%
experiments.append([1,160,50,'Max',0.26,'Final2'])
experiments.append([1,160,50,'Min',0.20,'Final2'])
experiments.append([1,160,50,'Mean',0.23,'Final2'])
experiments.append([1,160,50,'Val',0.23,'Final2'])
experiments.append([1,160,50,'Train',0.22,'Final2'])
experiments.append([1,160,50,'GenErr',0.22-0.20,'Final2'])
experiments.append([1,160,50,'GenBound',0.028,'Final2'])
experiments.append([1,160,50,'TrainTime',735,'Final2'])

# %%
experiments.append([1.5,160,50,'Max',0.28,'Final2'])
experiments.append([1.5,160,50,'Min',0.19,'Final2'])
experiments.append([1.5,160,50,'Mean',0.23,'Final2'])
experiments.append([1.5,160,50,'Val',0.27,'Final2'])
experiments.append([1.5,160,50,'Train',0.22,'Final2'])
experiments.append([1.5,160,50,'GenErr',0.22-0.19,'Final2'])
experiments.append([1.5,160,50,'GenBound',0.059,'Final2'])
experiments.append([1.5,160,50,'TrainTime',1274,'Final2'])

# %%
experiments.append([2,160,50,'Max',0.30,'Final2'])
experiments.append([2,160,50,'Min',0.21,'Final2'])
experiments.append([2,160,50,'Mean',0.25,'Final2'])
experiments.append([2,160,50,'Val',0.22,'Final2'])
experiments.append([2,160,50,'Train',0.23,'Final2'])
experiments.append([2,160,50,'GenErr',0.23-0.21,'Final2'])
experiments.append([2,160,50,'GenBound',0.072,'Final2'])
experiments.append([2,160,50,'TrainTime',332,'Final2'])

# %%
experiments.append([2,1600,50,'Max',0.26,'Final2'])
experiments.append([2,1600,50,'Min',0.24,'Final2'])
experiments.append([2,1600,50,'Mean',0.25,'Final2'])
experiments.append([2,1600,50,'Val',0.24,'Final2'])
experiments.append([2,1600,50,'Train',0.25,'Final2'])
experiments.append([2,1600,50,'GenErr',0.25-0.24,'Final2'])
experiments.append([2,1600,50,'GenBound',0.0066,'Final2'])
experiments.append([2,1600,50,'TrainTime',309,'Final2'])

# %%
experiments.append([1.5,1600,50,'Max',0.24,'Final2'])
experiments.append([1.5,1600,50,'Min',0.23,'Final2'])
experiments.append([1.5,1600,50,'Mean',0.24,'Final2'])
experiments.append([1.5,1600,50,'Val',0.23,'Final2'])
experiments.append([1.5,1600,50,'Train',0.23,'Final2'])
experiments.append([1.5,1600,50,'GenErr',0.23-0.23,'Final2'])
experiments.append([1.5,1600,50,'GenBound',0.0039,'Final2'])
experiments.append([1.5,1600,50,'TrainTime',1395,'Final2'])

# %%
experiments.append([1,1600,50,'Max',0.042,'Final2'])
experiments.append([1,1600,50,'Min',0.039,'Final2'])
experiments.append([1,1600,50,'Mean',0.040,'Final2'])
experiments.append([1,1600,50,'Val',0.037,'Final2'])
experiments.append([1,1600,50,'Train',0.036,'Final2'])
experiments.append([1,1600,50,'GenErr',0.037-0.036,'Final2'])
experiments.append([1,1600,50,'GenBound',0.0057,'Final2'])
experiments.append([1,1600,50,'TrainTime',25586,'Final2'])

# %%
experiments.append([0.5,1600,50,'Max',0.0011,'Final2'])
experiments.append([0.5,1600,50,'Min',0.00093,'Final2'])
experiments.append([0.5,1600,50,'Mean',0.0010,'Final2'])
experiments.append([0.5,1600,50,'Val',0.0011,'Final2'])
experiments.append([0.5,1600,50,'Train',0.00086,'Final2'])
experiments.append([0.5,1600,50,'GenErr',0.00093-0.00086,'Final2'])
experiments.append([0.5,1600,50,'GenBound',0.00023,'Final2'])
experiments.append([0.5,1600,50,'TrainTime',21470,'Final2'])

# %%
experiments.append([0.5,6400,50,'Max',0.00072,'Final2'])
experiments.append([0.5,6400,50,'Min',0.00071,'Final2'])
experiments.append([0.5,6400,50,'Mean',0.00071,'Final2'])
experiments.append([0.5,6400,50,'Val',0.00072,'Final2'])
experiments.append([0.5,6400,50,'Train',0.00067,'Final2'])
experiments.append([0.5,6400,50,'GenErr',0.00071-0.00067,'Final2'])
experiments.append([0.5,6400,50,'GenBound',0.000052,'Final2'])
experiments.append([0.5,6400,50,'TrainTime',24615,'Final2'])

# %%
experiments.append([1,6400,50,'Max',0.0046,'Final2'])
experiments.append([1,6400,50,'Min',0.0040,'Final2'])
experiments.append([1,6400,50,'Mean',0.0042,'Final2'])
experiments.append([1,6400,50,'Val',0.0039,'Final2'])
experiments.append([1,6400,50,'Train',0.0039,'Final2'])
experiments.append([1,6400,50,'GenEerr',0.0039-0.0039,'Final2'])
experiments.append([1,6400,50,'GenBound',0.00039,'Final2'])
experiments.append([1,6400,50,'TrainTime',48566,'Final2'])

# %%
experiments.append([1.5,6400,50,'Max',0.12,'Final2'])
experiments.append([1.5,6400,50,'Min',0.12,'Final2'])
experiments.append([1.5,6400,50,'Mean',0.12,'Final2'])
experiments.append([1.5,6400,50,'Val',0.12,'Final2'])
experiments.append([1.5,6400,50,'Train',0.11,'Final2'])
experiments.append([1.5,6400,50,'GenErr',0.12-0.11,'Final2'])
experiments.append([1.5,6400,50,'GenBound',0.0075,'Final2'])
experiments.append([1.5,6400,50,'TrainTime',37745,'Final2'])

# %%
experiments.append([2,6400,50,'Max',0.25,'Final2'])
experiments.append([2,6400,50,'Min',0.24,'Final2'])
experiments.append([2,6400,50,'Mean',0.25,'Final2'])
experiments.append([2,6400,50,'Val',0.25,'Final2'])
experiments.append([2,6400,50,'Train',0.24,'Final2'])
experiments.append([2,6400,50,'GenErr',0.24-0.24,'Final2'])
experiments.append([2,6400,50,'GenBound',0.0098,'Final2'])
experiments.append([2,6400,50,'TrainTime',2467,'Final2'])

# %%
experiments.append([0.5,1600,500,'Max',0.00015,'Final2'])
experiments.append([0.5,1600,500,'Min',0.00013,'Final2'])
experiments.append([0.5,1600,500,'Mean',0.00014,'Final2'])
experiments.append([0.5,1600,500,'Val',0.00015,'Final2'])
experiments.append([0.5,1600,500,'Train',0.000072,'Final2'])
experiments.append([0.5,1600,500,'GenErr',0.00013-0.000072,'Final2'])
experiments.append([0.5,1600,500,'GenBound',0.000079,'Final2'])
experiments.append([0.5,1600,500,'TrainTime',9179,'Final2'])

# %%
experiments.append([0.5,1600,1000,'Max',0.00027,'Final2'])
experiments.append([0.5,1600,1000,'Min',0.00022,'Final2'])
experiments.append([0.5,1600,1000,'Mean',0.00025,'Final2'])
experiments.append([0.5,1600,1000,'Val',0.00025,'Final2'])
experiments.append([0.5,1600,1000,'Train',0.00013,'Final2'])
experiments.append([0.5,1600,1000,'GenErr',0.00022-0.00013,'Final2'])
experiments.append([0.5,1600,1000,'GenBound',0.00014,'Final2'])
experiments.append([0.5,1600,1000,'TrainTime',5038,'Final2'])

# %%
experiments.append([1.0,1600,1000,'Max',0.0013,'Final2'])
experiments.append([1.0,1600,1000,'Min',0.00089,'Final2'])
experiments.append([1.0,1600,1000,'Mean',0.0011,'Final2'])
experiments.append([1.0,1600,1000,'Val',0.00093,'Final2'])
experiments.append([1.0,1600,1000,'Train',0.00065,'Final2'])
experiments.append([1.0,1600,1000,'GenErr',0.00089-0.00065,'Final2'])
experiments.append([1.0,1600,1000,'GenBound',0.00061,'Final2'])
experiments.append([1.0,1600,1000,'TrainTime',12298,'Final2'])

# %%
experiments.append([1.5,1600,1000,'Max',0.0065,'Final2'])
experiments.append([1.5,1600,1000,'Min',0.0061,'Final2'])
experiments.append([1.5,1600,1000,'Mean',0.0063,'Final2'])
experiments.append([1.5,1600,1000,'Val',0.0064,'Final2'])
experiments.append([1.5,1600,1000,'Train',0.0028,'Final2'])
experiments.append([1.5,1600,1000,'GenErr',0.0061-0.0028,'Final2'])
experiments.append([1.5,1600,1000,'GenBound',0.0037,'Final2'])
experiments.append([1.5,1600,1000,'TrainTime',20247,'Final2'])

# %%
experiments.append([2.0,1600,1000,'Max',0.028,'Final2'])
experiments.append([2.0,1600,1000,'Min',0.025,'Final2'])
experiments.append([2.0,1600,1000,'Mean',0.026,'Final2'])
experiments.append([2.0,1600,1000,'Val',0.027,'Final2'])
experiments.append([2.0,1600,1000,'Train',0.013,'Final2'])
experiments.append([2.0,1600,1000,'GenBound',0.014,'Final2'])
experiments.append([2.0,1600,1000,'TrainTime',33150,'Final2'])

# %%
experiments.append([1.0,1600,500,'Max',0.0031,'Final2'])
experiments.append([1.0,1600,500,'Min',0.0020,'Final2'])
experiments.append([1.0,1600,500,'Mean',0.0026,'Final2'])
experiments.append([1.0,1600,500,'Val',0.0020,'Final2'])
experiments.append([1.0,1600,500,'Train',0.0013,'Final2'])
experiments.append([1.0,1600,500,'GenBound',0.0019,'Final2'])
experiments.append([1.0,1600,500,'TrainTime',11896,'Final2'])

# %%
experiments.append([1.5,1600,500,'Max',0.0066,'Final2'])
experiments.append([1.5,1600,500,'Min',0.0061,'Final2'])
experiments.append([1.5,1600,500,'Mean',0.0064,'Final2'])
experiments.append([1.5,1600,500,'Val',0.0064,'Final2'])
experiments.append([1.5,1600,500,'Train',0.0022,'Final2'])
experiments.append([1.5,1600,500,'GenBound',0.0044,'Final2'])
experiments.append([1.5,1600,500,'TrainTime',27363,'Final2'])

# %%
experiments.append([2.0,1600,500,'Max',0.25,'Final2'])
experiments.append([2.0,1600,500,'Min',0.24,'Final2'])
experiments.append([2.0,1600,500,'Mean',0.25,'Final2'])
experiments.append([2.0,1600,500,'Val',0.26,'Final2'])
experiments.append([2.0,1600,500,'Train',0.24,'Final2'])
experiments.append([2.0,1600,500,'GenBound',0.016,'Final2'])
experiments.append([2.0,1600,500,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,1600,1000,'Max',0.25,'Final2'])
experiments.append([3.0,1600,1000,'Min',0.23,'Final2'])
experiments.append([3.0,1600,1000,'Mean',0.24,'Final2'])
experiments.append([3.0,1600,1000,'Val',0.24,'Final2'])
experiments.append([3.0,1600,1000,'Train',0.22,'Final2'])
experiments.append([3.0,1600,1000,'GenBound',0.024,'Final2'])
experiments.append([3.0,1600,1000,'TrainTime',302,'Final2'])

# %%
experiments.append([0.25,1600,1000,'Max',0.000022,'Final2'])
experiments.append([0.25,1600,1000,'Min',0.000019,'Final2'])
experiments.append([0.25,1600,1000,'Mean',0.000021,'Final2'])
experiments.append([0.25,1600,1000,'Val',0.000017,'Final2'])
experiments.append([0.25,1600,1000,'Train',0.00015,'Final2'])
experiments.append([0.25,1600,1000,'GenBound',0.0000063,'Final2'])
experiments.append([0.25,1600,1000,'TrainTime',5366,'Final2'])

# %%
experiments.append([0.75,1600,1000,'Max',0.00053,'Final2'])
experiments.append([0.75,1600,1000,'Min',0.00043,'Final2'])
experiments.append([0.75,1600,1000,'Mean',0.00048,'Final2'])
experiments.append([0.75,1600,1000,'Val',0.00047,'Final2'])
experiments.append([0.75,1600,1000,'Train',0.00027,'Final2'])
experiments.append([0.75,1600,1000,'GenBound',0.00026,'Final2'])
experiments.append([0.75,1600,1000,'TrainTime',6475,'Final2'])

# %%
experiments.append([1.25,1600,1000,'Max',0.0017,'Final2'])
experiments.append([1.25,1600,1000,'Min',0.0012,'Final2'])
experiments.append([1.25,1600,1000,'Mean',0.0015,'Final2'])
experiments.append([1.25,1600,1000,'Val',0.0017,'Final2'])
experiments.append([1.25,1600,1000,'Train',0.00051,'Final2'])
experiments.append([1.25,1600,1000,'GenBound',0.0012,'Final2'])
experiments.append([1.25,1600,1000,'TrainTime',19697,'Final2'])

# %%
experiments.append([1.75,1600,1000,'Max',0.015,'Final2'])
experiments.append([1.75,1600,1000,'Min',0.011,'Final2'])
experiments.append([1.75,1600,1000,'Mean',0.013,'Final2'])
experiments.append([1.75,1600,1000,'Val',0.013,'Final2'])
experiments.append([1.75,1600,1000,'Train',0.0060,'Final2'])
experiments.append([1.75,1600,1000,'GenBound',0.0086,'Final2'])
experiments.append([1.75,1600,1000,'TrainTime',27572,'Final2'])

# %%
experiments.append([1.75,16000,1000,'Max',0.0082,'Final2'])
experiments.append([1.75,16000,1000,'Min',0.0079,'Final2'])
experiments.append([1.75,16000,1000,'Mean',0.0081,'Final2'])
experiments.append([1.75,16000,1000,'Val',0.0081,'Final2'])
experiments.append([1.75,16000,1000,'Train',0.0078,'Final2'])
experiments.append([1.75,16000,1000,'GenBound',0.00046,'Final2'])
experiments.append([1.75,16000,1000,'TrainTime',22290,'Final2'])

# %%
experiments.append([1.5,16000,1000,'Max',0.0033,'Final2'])
experiments.append([1.5,16000,1000,'Min',0.0032,'Final2'])
experiments.append([1.5,16000,1000,'Mean',0.0032,'Final2'])
experiments.append([1.5,16000,1000,'Val',0.0033,'Final2'])
experiments.append([1.5,16000,1000,'Train',0.0031,'Final2'])
experiments.append([1.5,16000,1000,'GenBound',0.00023,'Final2'])
experiments.append([1.5,16000,1000,'TrainTime',15849,'Final2'])

# %%
experiments.append([0.5,16000,1000,'Max',0.00012,'Final2'])
experiments.append([0.5,16000,1000,'Min',0.00012,'Final2'])
experiments.append([0.5,16000,1000,'Mean',0.00012,'Final2'])
experiments.append([0.5,16000,1000,'Val',0.00011,'Final2'])
experiments.append([0.5,16000,1000,'Train',0.00011,'Final2'])
experiments.append([0.5,16000,1000,'GenBound',0.00001,'Final2'])
experiments.append([0.5,16000,1000,'TrainTime',5885,'Final2'])

# %%
experiments.append([2.0,16000,1000,'Max',0.011,'Final2'])
experiments.append([2.0,16000,1000,'Min',0.011,'Final2'])
experiments.append([2.0,16000,1000,'Mean',0.011,'Final2'])
experiments.append([2.0,16000,1000,'Val',0.011,'Final2'])
experiments.append([2.0,16000,1000,'Train',0.0097,'Final2'])
experiments.append([2.0,16000,1000,'GenBound',0.0011,'Final2'])
experiments.append([2.0,16000,1000,'TrainTime',31313,'Final2'])

# %%
experiments.append([4.0,1600,10000,'Max',0.26,'Final2'])
experiments.append([4.0,1600,10000,'Min',0.24,'Final2'])
experiments.append([4.0,1600,10000,'Mean',0.25,'Final2'])
experiments.append([4.0,1600,10000,'Val',0.25,'Final2'])
experiments.append([4.0,1600,10000,'Train',0.25,'Final2'])
experiments.append([4.0,1600,10000,'GenBound',0.011,'Final2'])
experiments.append([4.0,1600,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,1600,10000,'Max',0.25,'Final2'])
experiments.append([3.0,1600,10000,'Min',0.24,'Final2'])
experiments.append([3.0,1600,10000,'Mean',0.24,'Final2'])
experiments.append([3.0,1600,10000,'Val',0.24,'Final2'])
experiments.append([3.0,1600,10000,'Train',0.25,'Final2'])
experiments.append([3.0,1600,10000,'GenBound',0.0080,'Final2'])
experiments.append([3.0,1600,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([0.25,160,10000,'Max',0.0019,'Final2'])
experiments.append([0.25,160,10000,'Min',0.0014,'Final2'])
experiments.append([0.25,160,10000,'Mean',0.0015,'Final2'])
experiments.append([0.25,160,10000,'Val',0.0019,'Final2'])
experiments.append([0.25,160,10000,'Train',0.0010,'Final2'])
experiments.append([0.25,160,10000,'GenBound',0.00090,'Final2'])
experiments.append([0.25,160,10000,'TrainTime',1120,'Final2'])

# %%
experiments.append([0.25,1600,10000,'Max',0.00011,'Final2'])
experiments.append([0.25,1600,10000,'Min',0.00010,'Final2'])
experiments.append([0.25,1600,10000,'Mean',0.00010,'Final2'])
experiments.append([0.25,1600,10000,'Val',0.00011,'Final2'])
experiments.append([0.25,1600,10000,'Train',0.000055,'Final2'])
experiments.append([0.25,1600,10000,'GenBound',0.000052,'Final2'])
experiments.append([0.25,1600,10000,'TrainTime',1535,'Final2'])

# %%
experiments.append([3.0,160,10000,'Max',0.28,'Final2'])
experiments.append([3.0,160,10000,'Min',0.21,'Final2'])
experiments.append([3.0,160,10000,'Mean',0.25,'Final2'])
experiments.append([3.0,160,10000,'Val',0.28,'Final2'])
experiments.append([3.0,160,10000,'Train',0.19,'Final2'])
experiments.append([3.0,160,10000,'GenBound',0.088,'Final2'])
experiments.append([3.0,160,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([4.0,160,10000,'Max',0.31,'Final2'])
experiments.append([4.0,160,10000,'Min',0.25,'Final2'])
experiments.append([4.0,160,10000,'Mean',0.27,'Final2'])
experiments.append([4.0,160,10000,'Val',0.22,'Final2'])
experiments.append([4.0,160,10000,'Train',0.19,'Final2'])
experiments.append([4.0,160,10000,'GenBound',0.12,'Final2'])
experiments.append([4.0,160,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([4.0,160,100,'Max',0.29,'Final2'])
experiments.append([4.0,160,100,'Min',0.25,'Final2'])
experiments.append([4.0,160,100,'Mean',0.27,'Final2'])
experiments.append([4.0,160,100,'Val',0.29,'Final2'])
experiments.append([4.0,160,100,'Train',0.23,'Final2'])
experiments.append([4.0,160,100,'GenBound',0.059,'Final2'])
experiments.append([4.0,160,100,'TrainTime',886,'Final2'])

# %%
experiments.append([3.0,160,100,'Max',0.26,'Final2'])
experiments.append([3.0,160,100,'Min',0.23,'Final2'])
experiments.append([3.0,160,100,'Mean',0.24,'Final2'])
experiments.append([3.0,160,100,'Val',0.24,'Final2'])
experiments.append([3.0,160,100,'Train',0.21,'Final2'])
experiments.append([3.0,160,100,'GenBound',0.059,'Final2'])
experiments.append([3.0,160,100,'TrainTime',696,'Final2'])

# %%
experiments.append([0.25,160,100,'Max',0.00024,'Final2'])
experiments.append([0.25,160,100,'Min',0.00016,'Final2'])
experiments.append([0.25,160,100,'Mean',0.00021,'Final2'])
experiments.append([0.25,160,100,'Val',0.00027,'Final2'])
experiments.append([0.25,160,100,'Train',0.000031,'Final2'])
experiments.append([0.25,160,100,'GenBound',0.00021,'Final2'])
experiments.append([0.25,160,100,'TrainTime',11610,'Final2'])

# %%
experiments.append([0.25,16000,100,'Max',0.000041,'Final2'])
experiments.append([0.25,16000,100,'Min',0.000039,'Final2'])
experiments.append([0.25,16000,100,'Mean',0.000041,'Final2'])
experiments.append([0.25,16000,100,'Val',0.000039,'Final2'])
experiments.append([0.25,16000,100,'Train',0.000039,'Final2'])
experiments.append([0.25,16000,100,'GenBound',0.0000018,'Final2'])
experiments.append([0.25,16000,100,'TrainTime',13271,'Final2'])

# %%
experiments.append([3.0,16000,100,'Max',0.24,'Final2'])
experiments.append([3.0,16000,100,'Min',0.24,'Final2'])
experiments.append([3.0,16000,100,'Mean',0.24,'Final2'])
experiments.append([3.0,16000,100,'Val',0.24,'Final2'])
experiments.append([3.0,16000,100,'Train',0.24,'Final2'])
experiments.append([3.0,16000,100,'GenBound',0.0080,'Final2'])
experiments.append([3.0,16000,100,'TrainTime',4989,'Final2'])

# %%
experiments.append([3.0,16000,5000,'Max',0.23,'Final2'])
experiments.append([3.0,16000,5000,'Min',0.23,'Final2'])
experiments.append([3.0,16000,5000,'Mean',0.23,'Final2'])
experiments.append([3.0,16000,5000,'Val',0.23,'Final2'])
experiments.append([3.0,16000,5000,'Train',0.22,'Final2'])
experiments.append([3.0,16000,5000,'GenBound',0.011,'Final2'])
experiments.append([3.0,16000,5000,'TrainTime',2857,'Final2'])

# %%
experiments.append([0.25,16000,5000,'Max',0.00016,'Final2'])
experiments.append([0.25,16000,5000,'Min',0.00016,'Final2'])
experiments.append([0.25,16000,5000,'Mean',0.00016,'Final2'])
experiments.append([0.25,16000,5000,'Val',0.00016,'Final2'])
experiments.append([0.25,16000,5000,'Train',0.00012,'Final2'])
experiments.append([0.25,16000,5000,'GenBound',0.000046,'Final2'])
experiments.append([0.25,16000,5000,'TrainTime',1197,'Final2'])

# %%
experiments.append([2.5,6400,100,'Max',0.25,'Final2'])
experiments.append([2.5,6400,100,'Min',0.24,'Final2'])
experiments.append([2.5,6400,100,'Mean',0.24,'Final2'])
experiments.append([2.5,6400,100,'Val',0.24,'Final2'])
experiments.append([2.5,6400,100,'Train',0.25,'Final2'])
experiments.append([2.5,6400,100,'GenBound',0.0036,'Final2'])
experiments.append([2.5,6400,100,'TrainTime',324,'Final2'])

# %%
experiments.append([2.5,6400,500,'Max',0.24,'Final2'])
experiments.append([2.5,6400,500,'Min',0.23,'Final2'])
experiments.append([2.5,6400,500,'Mean',0.24,'Final2'])
experiments.append([2.5,6400,500,'Val',0.24,'Final2'])
experiments.append([2.5,6400,500,'Train',0.24,'Final2'])
experiments.append([2.5,6400,500,'GenBound',0.00013,'Final2'])
experiments.append([2.5,6400,500,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,6400,1000,'Max',0.25,'Final2'])
experiments.append([2.5,6400,1000,'Min',0.24,'Final2'])
experiments.append([2.5,6400,1000,'Mean',0.24,'Final2'])
experiments.append([2.5,6400,1000,'Val',0.24,'Final2'])
experiments.append([2.5,6400,1000,'Train',0.24,'Final2'])
experiments.append([2.5,6400,1000,'GenBound',0.0013,'Final2'])
experiments.append([2.5,6400,1000,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,6400,10000,'Max',0.22,'Final2'])
experiments.append([2.5,6400,10000,'Min',0.22,'Final2'])
experiments.append([2.5,6400,10000,'Mean',0.22,'Final2'])
experiments.append([2.5,6400,10000,'Val',0.22,'Final2'])
experiments.append([2.5,6400,10000,'Train',0.22,'Final2'])
experiments.append([2.5,6400,10000,'GenBound',0.0062,'Final2'])
experiments.append([2.5,6400,10000,'TrainTime',2246,'Final2'])

# %%
experiments.append([2.5,6400,5000,'Max',0.12,'Final2'])
experiments.append([2.5,6400,5000,'Min',0.12,'Final2'])
experiments.append([2.5,6400,5000,'Mean',0.12,'Final2'])
experiments.append([2.5,6400,5000,'Val',0.12,'Final2'])
experiments.append([2.5,6400,5000,'Train',0.11,'Final2'])
experiments.append([2.5,6400,5000,'GenBound',0.015,'Final2'])
experiments.append([2.5,6400,5000,'TrainTime',13778,'Final2'])

# %%
experiments.append([2.5,6400,30000,'Max',0.24,'Final2'])
experiments.append([2.5,6400,30000,'Min',0.23,'Final2'])
experiments.append([2.5,6400,30000,'Mean',0.24,'Final2'])
experiments.append([2.5,6400,30000,'Val',0.24,'Final2'])
experiments.append([2.5,6400,30000,'Train',0.24,'Final2'])
experiments.append([2.5,6400,30000,'GenBound',0.0053,'Final2'])
experiments.append([2.5,6400,30000,'TrainTime',1043,'Final2'])

# %%
experiments.append([3.0,6400,30000,'Max',0.24,'Final2'])
experiments.append([3.0,6400,30000,'Min',0.23,'Final2'])
experiments.append([3.0,6400,30000,'Mean',0.23,'Final2'])
experiments.append([3.0,6400,30000,'Val',0.24,'Final2'])
experiments.append([3.0,6400,30000,'Train',0.23,'Final2'])
experiments.append([3.0,6400,30000,'GenBound',0.0095,'Final2'])
experiments.append([3.0,6400,30000,'TrainTime',1523,'Final2'])

# %%
experiments.append([3.0,6400,10000,'Max',0.24,'Final2'])
experiments.append([3.0,6400,10000,'Min',0.23,'Final2'])
experiments.append([3.0,6400,10000,'Mean',0.24,'Final2'])
experiments.append([3.0,6400,10000,'Val',0.24,'Final2'])
experiments.append([3.0,6400,10000,'Train',0.23,'Final2'])
experiments.append([3.0,6400,10000,'GenBound',0.0054,'Final2'])
experiments.append([3.0,6400,10000,'TrainTime',1245,'Final2'])

# %%
experiments.append([3.0,6400,5000,'Max',0.24,'Final2'])
experiments.append([3.0,6400,5000,'Min',0.24,'Final2'])
experiments.append([3.0,6400,5000,'Mean',0.24,'Final2'])
experiments.append([3.0,6400,5000,'Val',0.24,'Final2'])
experiments.append([3.0,6400,5000,'Train',0.24,'Final2'])
experiments.append([3.0,6400,5000,'GenBound',0.0061,'Final2'])
experiments.append([3.0,6400,5000,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,6400,1000,'Max',0.24,'Final2'])
experiments.append([3.0,6400,1000,'Min',0.24,'Final2'])
experiments.append([3.0,6400,1000,'Mean',0.24,'Final2'])
experiments.append([3.0,6400,1000,'Val',0.24,'Final2'])
experiments.append([3.0,6400,1000,'Train',0.24,'Final2'])
experiments.append([3.0,6400,1000,'GenBound',0.0088,'Final2'])
experiments.append([3.0,6400,1000,'TrainTime',554,'Final2'])

# %%
experiments.append([3.0,6400,100,'Max',0.24,'Final2'])
experiments.append([3.0,6400,100,'Min',0.24,'Final2'])
experiments.append([3.0,6400,100,'Mean',0.24,'Final2'])
experiments.append([3.0,6400,100,'Val',0.24,'Final2'])
experiments.append([3.0,6400,100,'Train',0.24,'Final2'])
experiments.append([3.0,6400,100,'GenBound',0.0068,'Final2'])
experiments.append([3.0,6400,100,'TrainTime',2556,'Final2'])

# %%
experiments.append([3.0,6400,500,'Max',0.24,'Final2'])
experiments.append([3.0,6400,500,'Min',0.24,'Final2'])
experiments.append([3.0,6400,500,'Mean',0.24,'Final2'])
experiments.append([3.0,6400,500,'Val',0.23,'Final2'])
experiments.append([3.0,6400,500,'Train',0.24,'Final2'])
experiments.append([3.0,6400,500,'GenBound',0.0024,'Final2'])
experiments.append([3.0,6400,500,'TrainTime',307,'Final2'])

# %%
experiments.append([3.0,6400,2000,'Max',0.088,'Final2'])
experiments.append([3.0,6400,2000,'Min',0.081,'Final2'])
experiments.append([3.0,6400,2000,'Mean',0.085,'Final2'])
experiments.append([3.0,6400,2000,'Val',0.084,'Final2'])
experiments.append([3.0,6400,2000,'Train',0.070,'Final2'])
experiments.append([3.0,6400,2000,'GenBound',0.018,'Final2'])
experiments.append([3.0,6400,2000,'TrainTime',50000,'Final2'])

# %%
experiments.append([2.5,6400,2000,'Max',0.037,'Final2'])
experiments.append([2.5,6400,2000,'Min',0.036,'Final2'])
experiments.append([2.5,6400,2000,'Mean',0.037,'Final2'])
experiments.append([2.5,6400,2000,'Val',0.037,'Final2'])
experiments.append([2.5,6400,2000,'Train',0.030,'Final2'])
experiments.append([2.5,6400,2000,'GenBound',0.0074,'Final2'])
experiments.append([2.5,6400,2000,'TrainTime',35367,'Final2'])

# %%
experiments.append([2.0,6400,2000,'Max',0.019,'Final2'])
experiments.append([2.0,6400,2000,'Min',0.018,'Final2'])
experiments.append([2.0,6400,2000,'Mean',0.019,'Final2'])
experiments.append([2.0,6400,2000,'Val',0.018,'Final2'])
experiments.append([2.0,6400,2000,'Train',0.015,'Final2'])
experiments.append([2.0,6400,2000,'GenBound',0.0045,'Final2'])
experiments.append([2.0,6400,2000,'TrainTime',22145,'Final2'])

# %%
experiments.append([1.5,6400,2000,'Max',0.0058,'Final2'])
experiments.append([1.5,6400,2000,'Min',0.0058,'Final2'])
experiments.append([1.5,6400,2000,'Mean',0.0058,'Final2'])
experiments.append([1.5,6400,2000,'Val',0.0058,'Final2'])
experiments.append([1.5,6400,2000,'Train',0.0052,'Final2'])
experiments.append([1.5,6400,2000,'GenBound',0.00057,'Final2'])
experiments.append([1.5,6400,2000,'TrainTime',11119,'Final2'])

# %% [markdown]
# August 13, 2024

# %%
experiments.append([1.0,6400,2000,'Max',0.0024,'Final2'])
experiments.append([1.0,6400,2000,'Min',0.0022,'Final2'])
experiments.append([1.0,6400,2000,'Mean',0.0024,'Final2'])
experiments.append([1.0,6400,2000,'Val',0.0024,'Final2'])
experiments.append([1.0,6400,2000,'Train',0.0025,'Final2'])
experiments.append([1.0,6400,2000,'GenBound',0.0000052,'Final2'])
experiments.append([1.0,6400,2000,'TrainTime',5258,'Final2'])

# %%
experiments.append([0.5,6400,2000,'Max',0.00042,'Final2'])
experiments.append([0.5,6400,2000,'Min',0.00040,'Final2'])
experiments.append([0.5,6400,2000,'Mean',0.00041,'Final2'])
experiments.append([0.5,6400,2000,'Val',0.00042,'Final2'])
experiments.append([0.5,6400,2000,'Train',0.00038,'Final2'])
experiments.append([0.5,6400,2000,'GenBound',0.000045,'Final2'])
experiments.append([0.5,6400,2000,'TrainTime',2676,'Final2'])

# %%
experiments.append([0.5,160,2000,'Max',0.0089,'Final2'])
experiments.append([0.5,160,2000,'Min',0.0032,'Final2'])
experiments.append([0.5,160,2000,'Mean',0.0055,'Final2'])
experiments.append([0.5,160,2000,'Val',0.0044,'Final2'])
experiments.append([0.5,160,2000,'Train',0.00012,'Final2'])
experiments.append([0.5,160,2000,'GenBound',0.0088,'Final2'])
experiments.append([0.5,160,2000,'TrainTime',4418,'Final2'])

# %%
experiments.append([2.0,160,2000,'Max',0.30,'Final2'])
experiments.append([2.0,160,2000,'Min',0.25,'Final2'])
experiments.append([2.0,160,2000,'Mean',0.27,'Final2'])
experiments.append([2.0,160,2000,'Val',0.24,'Final2'])
experiments.append([2.0,160,2000,'Train',0.24,'Final2'])
experiments.append([2.0,160,2000,'GenBound',0.061,'Final2'])
experiments.append([2.0,160,2000,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,2000,'Max',0.28,'Final2'])
experiments.append([3.0,160,2000,'Min',0.23,'Final2'])
experiments.append([3.0,160,2000,'Mean',0.26,'Final2'])
experiments.append([3.0,160,2000,'Val',0.32,'Final2'])
experiments.append([3.0,160,2000,'Train',0.19,'Final2'])
experiments.append([3.0,160,2000,'GenBound',0.098,'Final2'])
experiments.append([3.0,160,2000,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,20000,'Max',0.31,'Final2'])
experiments.append([3.0,160,20000,'Min',0.24,'Final2'])
experiments.append([3.0,160,20000,'Mean',0.28,'Final2'])
experiments.append([3.0,160,20000,'Val',0.30,'Final2'])
experiments.append([3.0,160,20000,'Train',0.18,'Final2'])
experiments.append([3.0,160,20000,'GenBound',0.14,'Final2'])
experiments.append([3.0,160,20000,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,200,'Max',0.27,'Final2'])
experiments.append([3.0,160,200,'Min',0.26,'Final2'])
experiments.append([3.0,160,200,'Mean',0.26,'Final2'])
experiments.append([3.0,160,200,'Val',0.22,'Final2'])
experiments.append([3.0,160,200,'Train',0.25,'Final2'])
experiments.append([3.0,160,200,'GenBound',0.022,'Final2'])
experiments.append([3.0,160,200,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,10000,'Max',0.28,'Final2'])
experiments.append([3.0,160,10000,'Min',0.22,'Final2'])
experiments.append([3.0,160,10000,'Mean',0.26,'Final2'])
experiments.append([3.0,160,10000,'Val',0.28,'Final2'])
experiments.append([3.0,160,10000,'Train',0.21,'Final2'])
experiments.append([3.0,160,10000,'GenBound',0.065,'Final2'])
experiments.append([3.0,160,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,1000,'Max',0.27,'Final2'])
experiments.append([3.0,160,1000,'Min',0.21,'Final2'])
experiments.append([3.0,160,1000,'Mean',0.24,'Final2'])
experiments.append([3.0,160,1000,'Val',0.27,'Final2'])
experiments.append([3.0,160,1000,'Train',0.22,'Final2'])
experiments.append([3.0,160,1000,'GenBound',0.049,'Final2'])
experiments.append([3.0,160,1000,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,100,'Max',0.25,'Final2'])
experiments.append([3.0,160,100,'Min',0.22,'Final2'])
experiments.append([3.0,160,100,'Mean',0.24,'Final2'])
experiments.append([3.0,160,100,'Val',0.23,'Final2'])
experiments.append([3.0,160,100,'Train',0.21,'Final2'])
experiments.append([3.0,160,100,'GenBound',0.040,'Final2'])
experiments.append([3.0,160,100,'TrainTime',406,'Final2'])

# %%
experiments.append([3.0,160,500,'Max',0.24,'Final2'])
experiments.append([3.0,160,500,'Min',0.20,'Final2'])
experiments.append([3.0,160,500,'Mean',0.23,'Final2'])
experiments.append([3.0,160,500,'Val',0.25,'Final2'])
experiments.append([3.0,160,500,'Train',0.19,'Final2'])
experiments.append([3.0,160,500,'GenBound',0.051,'Final2'])
experiments.append([3.0,160,500,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,50,'Max',0.27,'Final2'])
experiments.append([3.0,160,50,'Min',0.19,'Final2'])
experiments.append([3.0,160,50,'Mean',0.24,'Final2'])
experiments.append([3.0,160,50,'Val',0.28,'Final2'])
experiments.append([3.0,160,50,'Train',0.24,'Final2'])
experiments.append([3.0,160,50,'GenBound',0.029,'Final2'])
experiments.append([3.0,160,50,'TrainTime',302,'Final2'])

# %%
experiments.append([3.0,160,5000,'Max',0.26,'Final2'])
experiments.append([3.0,160,5000,'Min',0.25,'Final2'])
experiments.append([3.0,160,5000,'Mean',0.26,'Final2'])
experiments.append([3.0,160,5000,'Val',0.22,'Final2'])
experiments.append([3.0,160,5000,'Train',0.16,'Final2'])
experiments.append([3.0,160,5000,'GenBound',0.10,'Final2'])
experiments.append([3.0,160,5000,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,160,5000,'Max',0.28,'Final2'])
experiments.append([2.5,160,5000,'Min',0.24,'Final2'])
experiments.append([2.5,160,5000,'Mean',0.26,'Final2'])
experiments.append([2.5,160,5000,'Val',0.27,'Final2'])
experiments.append([2.5,160,5000,'Train',0.21,'Final2'])
experiments.append([2.5,160,5000,'GenBound',0.072,'Final2'])
experiments.append([2.5,160,5000,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,160,500,'Max',0.26,'Final2'])
experiments.append([2.5,160,500,'Min',0.23,'Final2'])
experiments.append([2.5,160,500,'Mean',0.24,'Final2'])
experiments.append([2.5,160,500,'Val',0.22,'Final2'])
experiments.append([2.5,160,500,'Train',0.25,'Final2'])
experiments.append([2.5,160,500,'GenBound',0.013,'Final2'])
experiments.append([2.5,160,500,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,160,500,'Max',0.27,'Final2'])
experiments.append([2.5,160,500,'Min',0.19,'Final2'])
experiments.append([2.5,160,500,'Mean',0.23,'Final2'])
experiments.append([2.5,160,500,'Val',0.23,'Final2'])
experiments.append([2.5,160,500,'Train',0.30,'Final2'])
experiments.append([2.5,160,500,'GenBound',0.020,'Final2'])
experiments.append([2.5,160,500,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,160,100,'Max',0.30,'Final2'])
experiments.append([2.5,160,100,'Min',0.22,'Final2'])
experiments.append([2.5,160,100,'Mean',0.25,'Final2'])
experiments.append([2.5,160,100,'Val',0.28,'Final2'])
experiments.append([2.5,160,100,'Train',0.25,'Final2'])
experiments.append([2.5,160,100,'GenBound',0.045,'Final2'])
experiments.append([2.5,160,100,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,160,1000,'Max',0.30,'Final2'])
experiments.append([2.5,160,1000,'Min',0.24,'Final2'])
experiments.append([2.5,160,1000,'Mean',0.27,'Final2'])
experiments.append([2.5,160,1000,'Val',0.20,'Final2'])
experiments.append([2.5,160,1000,'Train',0.22,'Final2'])
experiments.append([2.5,160,1000,'GenBound',0.076,'Final2'])
experiments.append([2.5,160,1000,'TrainTime',302,'Final2'])

# %%
experiments.append([2.5,160,10000,'Max',0.28,'Final2'])
experiments.append([2.5,160,10000,'Min',0.21,'Final2'])
experiments.append([2.5,160,10000,'Mean',0.24,'Final2'])
experiments.append([2.5,160,10000,'Val',0.27,'Final2'])
experiments.append([2.5,160,10000,'Train',0.21,'Final2'])
experiments.append([2.5,160,10000,'GenBound',0.069,'Final2'])
experiments.append([2.5,160,10000,'TrainTime',302,'Final2'])

# %%
experiments.append([0.5,160,5000,'Max',0.0027,'Final'])
experiments.append([0.5,160,5000,'Min',0.0020,'Final'])
experiments.append([0.5,160,5000,'Mean',0.0023,'Final'])
experiments.append([0.5,160,5000,'Val',0.0019,'Final'])
experiments.append([0.5,160,5000,'Train',4.9e-5,'Final'])

# %%
experiments.append([2,160,5000,'Max',0.28,'Final'])
experiments.append([2,160,5000,'Min',0.25,'Final'])
experiments.append([2,160,5000,'Mean',0.26,'Final'])
experiments.append([2,160,5000,'Val',0.29,'Final'])
experiments.append([2,160,5000,'Train',0.17,'Final'])

# %%
experiments.append([1.5,160,5000,'Max',0.25,'Final'])
experiments.append([1.5,160,5000,'Min',0.23,'Final'])
experiments.append([1.5,160,5000,'Mean',0.24,'Final'])
experiments.append([1.5,160,5000,'Val',0.21,'Final'])
experiments.append([1.5,160,5000,'Train',0.20,'Final'])

# %%
experiments.append([1.5,160,500,'Max',0.25,'Final'])
experiments.append([1.5,160,500,'Min',0.23,'Final'])
experiments.append([1.5,160,500,'Mean',0.24,'Final'])
experiments.append([1.5,160,500,'Val',0.22,'Final'])
experiments.append([1.5,160,500,'Train',0.21,'Final'])

# %%
experiments.append([2,160,500,'Max',0.27,'Final'])
experiments.append([2,160,500,'Min',0.24,'Final'])
experiments.append([2,160,500,'Mean',0.25,'Final'])
experiments.append([2,160,500,'Val',0.30,'Final'])
experiments.append([2,160,500,'Train',0.26,'Final'])

# %%
experiments.append([1,160,500,'Max',0.27,'Final'])
experiments.append([1,160,500,'Min',0.22,'Final'])
experiments.append([1,160,500,'Mean',0.24,'Final'])
experiments.append([1,160,500,'Val',0.24,'Final'])
experiments.append([1,160,500,'Train',0.25,'Final'])

# %%
experiments.append([0.5,160,500,'Max',0.016,'Final'])
experiments.append([0.5,160,500,'Min',0.013,'Final'])
experiments.append([0.5,160,500,'Mean',0.015,'Final'])
experiments.append([0.5,160,500,'Val',0.011,'Final'])
experiments.append([0.5,160,500,'Train',0.0050,'Final'])

# %%
experiments.append([0.5,1600,500,'Max',0.0044,'Final'])
experiments.append([0.5,1600,500,'Min',0.0044,'Final'])
experiments.append([0.5,1600,500,'Mean',0.0044,'Final'])
experiments.append([0.5,1600,500,'Val',0.0044,'Final'])
experiments.append([0.5,1600,500,'Train',0.0037,'Final'])

# %%
experiments.append([1,1600,500,'Max',0.104,'Final'])
experiments.append([1,1600,500,'Min',0.096,'Final'])
experiments.append([1,1600,500,'Mean',0.100,'Final'])
experiments.append([1,1600,500,'Val',0.103,'Final'])
experiments.append([1,1600,500,'Train',0.092,'Final'])

# %%
experiments.append([1.5,1600,500,'Max',0.19,'Final'])
experiments.append([1.5,1600,500,'Min',0.18,'Final'])
experiments.append([1.5,1600,500,'Mean',0.18,'Final'])
experiments.append([1.5,1600,500,'Val',0.18,'Final'])
experiments.append([1.5,1600,500,'Train',0.16,'Final'])

# %%
experiments.append([2,1600,500,'Max',0.25,'Final'])
experiments.append([2,1600,500,'Min',0.24,'Final'])
experiments.append([2,1600,500,'Mean',0.24,'Final'])
experiments.append([2,1600,500,'Val',0.25,'Final'])
experiments.append([2,1600,500,'Train',0.24,'Final'])

# %%
experiments.append([2,1600,5000,'Max',0.19,'Final'])
experiments.append([2,1600,5000,'Min',0.18,'Final'])
experiments.append([2,1600,5000,'Mean',0.19,'Final'])
experiments.append([2,1600,5000,'Val',0.18,'Final'])
experiments.append([2,1600,5000,'Train',0.15,'Final'])

# %%
experiments.append([1.5,1600,5000,'Max',0.063,'Final'])
experiments.append([1.5,1600,5000,'Min',0.061,'Final'])
experiments.append([1.5,1600,5000,'Mean',0.062,'Final'])
experiments.append([1.5,1600,5000,'Val',0.060,'Final'])
experiments.append([1.5,1600,5000,'Train',0.046,'Final'])

# %%
experiments.append([1,1600,5000,'Max',0.0059,'Final'])
experiments.append([1,1600,5000,'Min',0.0051,'Final'])
experiments.append([1,1600,5000,'Mean',0.0055,'Final'])
experiments.append([1,1600,5000,'Val',0.0053,'Final'])
experiments.append([1,1600,5000,'Train',0.0042,'Final'])

# %%
experiments.append([0.5,1600,5000,'Max',8.9e-5,'Final'])
experiments.append([0.5,1600,5000,'Min',6.7e-5,'Final'])
experiments.append([0.5,1600,5000,'Mean',8.0e-5,'Final'])
experiments.append([0.5,1600,5000,'Val',7.3e-5,'Final'])
experiments.append([0.5,1600,5000,'Train',3.4e-5,'Final'])

# %%
experiments.append([0.5,1600,10000,'Max',0.00083,'Final'])
experiments.append([0.5,1600,10000,'Min',0.00080,'Final'])
experiments.append([0.5,1600,10000,'Mean',0.00082,'Final'])
experiments.append([0.5,1600,10000,'Val',0.00081,'Final'])
experiments.append([0.5,1600,10000,'Train',0.00053,'Final'])

# %%
experiments.append([1,1600,10000,'Max',0.013,'Final'])
experiments.append([1,1600,10000,'Min',0.012,'Final'])
experiments.append([1,1600,10000,'Mean',0.012,'Final'])
experiments.append([1,1600,10000,'Val',0.012,'Final'])
experiments.append([1,1600,10000,'Train',0.010,'Final'])

# %%
experiments.append([1.5,1600,10000,'Max',0.053,'Final'])
experiments.append([1.5,1600,10000,'Min',0.047,'Final'])
experiments.append([1.5,1600,10000,'Mean',0.050,'Final'])
experiments.append([1.5,1600,10000,'Val',0.048,'Final'])
experiments.append([1.5,1600,10000,'Train',0.037,'Final'])

# %%
experiments.append([2,1600,10000,'Max',0.25,'Final'])
experiments.append([2,1600,10000,'Min',0.24,'Final'])
experiments.append([2,1600,10000,'Mean',0.25,'Final'])
experiments.append([2,1600,10000,'Val',0.25,'Final'])
experiments.append([2,1600,10000,'Train',0.23,'Final'])

# %%
experiments.append([2,160,10000,'Max',0.29,'Final'])
experiments.append([2,160,10000,'Min',0.23,'Final'])
experiments.append([2,160,10000,'Mean',0.26,'Final'])
experiments.append([2,160,10000,'Val',0.26,'Final'])
experiments.append([2,160,10000,'Train',0.22,'Final'])

# %%
experiments.append([1.5,160,10000,'Max',0.27,'Final'])
experiments.append([1.5,160,10000,'Min',0.21,'Final'])
experiments.append([1.5,160,10000,'Mean',0.25,'Final'])
experiments.append([1.5,160,10000,'Val',0.25,'Final'])
experiments.append([1.5,160,10000,'Train',0.14,'Final'])

# %%
experiments.append([1,160,10000,'Max',0.057,'Final'])
experiments.append([1,160,10000,'Min',0.048,'Final'])
experiments.append([1,160,10000,'Mean',0.052,'Final'])
experiments.append([1,160,10000,'Val',0.055,'Final'])
experiments.append([1,160,10000,'Train',0.0015,'Final'])

# %%
experiments.append([0.5,160,10000,'Max',0.0046,'Final'])
experiments.append([0.5,160,10000,'Min',0.0036,'Final'])
experiments.append([0.5,160,10000,'Mean',0.0040,'Final'])
experiments.append([0.5,160,10000,'Val',0.0035,'Final'])
experiments.append([0.5,160,10000,'Train',0.00098,'Final'])

# %%
experiments.append([0.5,6400,10000,'Max',0.00091,'Final'])
experiments.append([0.5,6400,10000,'Min',0.00087,'Final'])
experiments.append([0.5,6400,10000,'Mean',0.00090,'Final'])
experiments.append([0.5,6400,10000,'Val',0.00090,'Final'])
experiments.append([0.5,6400,10000,'Train',0.00061,'Final'])

# %%
experiments.append([1,6400,10000,'Max',0.0072,'Final'])
experiments.append([1,6400,10000,'Min',0.0068,'Final'])
experiments.append([1,6400,10000,'Mean',0.0069,'Final'])
experiments.append([1,6400,10000,'Val',0.0069,'Final'])
experiments.append([1,6400,10000,'Train',0.0073,'Final'])

# %%
experiments.append([1.5,6400,10000,'Max',0.049,'Final'])
experiments.append([1.5,6400,10000,'Min',0.047,'Final'])
experiments.append([1.5,6400,10000,'Mean',0.046,'Final'])
experiments.append([1.5,6400,10000,'Val',0.047,'Final'])
experiments.append([1.5,6400,10000,'Train',0.045,'Final'])

# %%
experiments.append([2,6400,10000,'Max',0.17,'Final'])
experiments.append([2,6400,10000,'Min',0.17,'Final'])
experiments.append([2,6400,10000,'Mean',0.17,'Final'])
experiments.append([2,6400,10000,'Val',0.17,'Final'])
experiments.append([2,6400,10000,'Train',0.16,'Final'])

# %%
experiments.append([2,6400,5000,'Max',0.17,'Final'])
experiments.append([2,6400,5000,'Min',0.16,'Final'])
experiments.append([2,6400,5000,'Mean',0.16,'Final'])
experiments.append([2,6400,5000,'Val',0.16,'Final'])
experiments.append([2,6400,5000,'Train',0.15,'Final'])

# %%
experiments.append([1.5,6400,5000,'Max',0.059,'Final'])
experiments.append([1.5,6400,5000,'Min',0.056,'Final'])
experiments.append([1.5,6400,5000,'Mean',0.058,'Final'])
experiments.append([1.5,6400,5000,'Val',0.058,'Final'])
experiments.append([1.5,6400,5000,'Train',0.054,'Final'])

# %%
experiments.append([1,6400,5000,'Max',0.0032,'Final'])
experiments.append([1,6400,5000,'Min',0.0030,'Final'])
experiments.append([1,6400,5000,'Mean',0.0031,'Final'])
experiments.append([1,6400,5000,'Val',0.0031,'Final'])
experiments.append([1,6400,5000,'Train',0.0029,'Final'])

# %%
experiments.append([0.5,6400,5000,'Max',0.00011,'Final'])
experiments.append([0.5,6400,5000,'Min',0.00011,'Final'])
experiments.append([0.5,6400,5000,'Mean',0.00011,'Final'])
experiments.append([0.5,6400,5000,'Val',0.00011,'Final'])
experiments.append([0.5,6400,5000,'Train',8.1e-5,'Final'])

# %%
experiments.append([0.5,6400,500,'Max',0.0081,'Final'])
experiments.append([0.5,6400,500,'Min',0.0077,'Final'])
experiments.append([0.5,6400,500,'Mean',0.0075,'Final'])
experiments.append([0.5,6400,500,'Val',0.0075,'Final'])
experiments.append([0.5,6400,500,'Train',0.0072,'Final'])

# %%
experiments.append([1,6400,500,'Max',0.12,'Final'])
experiments.append([1,6400,500,'Min',0.12,'Final'])
experiments.append([1,6400,500,'Mean',0.12,'Final'])
experiments.append([1,6400,500,'Val',0.12,'Final'])
experiments.append([1,6400,500,'Train',0.12,'Final'])

# %%
experiments.append([1.5,6400,500,'Max',0.21,'Final'])
experiments.append([1.5,6400,500,'Min',0.21,'Final'])
experiments.append([1.5,6400,500,'Mean',0.21,'Final'])
experiments.append([1.5,6400,500,'Val',0.21,'Final'])
experiments.append([1.5,6400,500,'Train',0.20,'Final'])

# %%
experiments.append([2.0,6400,500,'Max',0.24,'Final'])
experiments.append([2.0,6400,500,'Min',0.24,'Final'])
experiments.append([2.0,6400,500,'Mean',0.24,'Final'])
experiments.append([2.0,6400,500,'Val',0.24,'Final'])
experiments.append([2.0,6400,500,'Train',0.24,'Final'])

# %%
experiments.append([1.5,6400,100,'Max',0.016,'Final2'])
experiments.append([1.5,6400,100,'Min',0.016,'Final2'])
experiments.append([1.5,6400,100,'Mean',0.016,'Final2'])
experiments.append([1.5,6400,100,'Val',0.016,'Final2'])
experiments.append([1.5,6400,100,'Train',0.015,'Final2'])
experiments.append([1.5,6400,100,'GenBound',0.0013,'Final2'])
experiments.append([1.5,6400,100,'TrainTime',50000,'Final2'])

# %%
column_values = ['Scale', 'N', 'M','Type','Value','Set']

# %%
experiments_df = pd.DataFrame(experiments,columns = column_values)

# %%
experiments_df.head()
# Out:
#    Scale    N     M   Type  Value    Set
# 0    1.0  160  5000    Max  0.062  Early
# 1    1.0  160  5000   Mean  0.057  Early
# 2    1.0  160  5000    Min  0.051  Early
# 3    1.0  160  5000    Val  0.050  Early
# 4    1.0  160  5000  Train  0.003  Early

# %%
final_df = experiments_df[experiments_df['Set']=='Final2']

print(final_df.head())
# Out:
#     Scale     N    M   Type   Value     Set
# 45    2.0  6400  500    Max  0.0055  Final2
# 46    2.0  6400  500    Min  0.0053  Final2
# 47    2.0  6400  500   Mean  0.0054  Final2
# 48    2.0  6400  500    Val  0.0054  Final2
# 49    2.0  6400  500  Train  0.0043  Final2

# %%
ax = sns.scatterplot(x='N', y='Value', style='Scale', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[final_df['Type']=='GenBound'])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot')
plt.yscale('log')

plt.xlabel('N (Samples)')
plt.ylabel('Emperical Generalization Bound')

X_plot = np.linspace(1, 6400, 100)
Y_plot = 2/np.sqrt(X_plot)

plt.plot(X_plot, Y_plot, color='r')
plt.show()

# %%
ax = sns.scatterplot(x='N', y='Value', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['Scale']==0.5)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (Scale=0.5)')
plt.yscale('log')

plt.xlabel('N (Samples)')
plt.ylabel('Emperical Generalization Bound')

X_plot = np.linspace(1, 16000, 100)
Y_plot = .02/np.sqrt(X_plot)

plt.plot(X_plot, Y_plot, color='r')
plt.show()

# %%
ax = sns.scatterplot(x='N', y='Value', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['Scale']==1.0)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (Scale=1.0)')
plt.yscale('log')

plt.xlabel('N (Samples)')
plt.ylabel('Emperical Generalization Bound')

X_plot = np.linspace(1, 6400, 100)
Y_plot = .1/np.sqrt(X_plot)

plt.plot(X_plot, Y_plot, color='r')
plt.show()

# %%
ax = sns.scatterplot(x='N', y='Value', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['Scale']==2.0)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (Scale=2.0)')
plt.yscale('log')

plt.xlabel('N (Samples)')
plt.ylabel('Emperical Generalization Bound')

X_plot = np.linspace(1, 16000, 100)
Y_plot = 1/np.sqrt(X_plot)

plt.plot(X_plot, Y_plot, color='r')
plt.show()

# %%
ax = sns.scatterplot(x='N', y='Value', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['Scale']==1.5)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (Scale=1.5)')
plt.yscale('log')

plt.xlabel('N (Samples)')
plt.ylabel('Emperical Generalization Bound')

X_plot = np.linspace(1, 16000, 100)
Y_plot = .5/np.sqrt(X_plot)

plt.plot(X_plot, Y_plot, color='r')
plt.show()

# %%
ax = sns.scatterplot(x='Scale', y='Value', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (N=160)')
#plt.yscale('log')

plt.xlabel('Scale')
plt.ylabel('Emperical Generalization Bound')

X_plot = np.linspace(0.5, 2, 32)
Y_plot = 0.1*X_plot-.02
X2_plot = np.linspace(0.5, 2, 32)
Y2_plot = 0.03*X_plot+.01

plt.plot(X_plot, Y_plot, color='r')
plt.plot(X2_plot, Y2_plot, color='g')

plt.show()

# %%
ax = sns.scatterplot(x='Scale', y='Value', hue='M', style='Type', palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='GenBound')|(final_df['Type']=='GenErr'))&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (N=160)')
plt.yscale('log')

plt.xlabel('Scale')
plt.ylabel('Emperical Generalization Bound')

plt.show()

# %%
ax = sns.scatterplot(x='Scale', y='Value', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['N']==1600)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (N=1600)')
plt.yscale('log')

plt.xlabel('Scale')
plt.ylabel('Emperical Generalization Bound')

#X_plot = np.linspace(0.25, 4, 200)
#Y_plot = 0.01*X_plot-.003
#X2_plot = np.linspace(0.25, 4, 200)
#Y2_plot = 0.003*X_plot

#plt.plot(X_plot, Y_plot, color='r')
#plt.plot(X2_plot, Y2_plot, color='g')

plt.show()

# %%
ax = sns.lineplot(x='Scale', y='Value',markers=True , style='M', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['N']==1600)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (N=1600)')
plt.yscale('log')

plt.xlabel('Scale')
plt.ylabel('Emperical Generalization Bound')

#X_plot = np.linspace(0.25, 4, 200)
#Y_plot = 0.01*X_plot-.003
#X2_plot = np.linspace(0.25, 4, 200)
#Y2_plot = 0.003*X_plot

#plt.plot(X_plot, Y_plot, color='r')
#plt.plot(X2_plot, Y2_plot, color='g')

plt.show()

# %%
ax = sns.lineplot(x='Scale', y='Value',markers=True , style='M', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (N=160)')
plt.yscale('log')

plt.xlabel('Scale')
plt.ylabel('Emperical Generalization Bound')

#X_plot = np.linspace(0.25, 4, 200)
#Y_plot = 0.01*X_plot-.003
#X2_plot = np.linspace(0.25, 4, 200)
#Y2_plot = 0.003*X_plot

#plt.plot(X_plot, Y_plot, color='r')
#plt.plot(X2_plot, Y2_plot, color='g')

plt.show()

# %%
ax = sns.lineplot(x='Scale', y='Value',markers=True , style='M', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['N']==16000)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (N=16000)')
plt.yscale('log')

plt.xlabel('Scale')
plt.ylabel('Emperical Generalization Bound')

#X_plot = np.linspace(0.25, 4, 200)
#Y_plot = 0.01*X_plot-.003
#X2_plot = np.linspace(0.25, 4, 200)
#Y2_plot = 0.003*X_plot

#plt.plot(X_plot, Y_plot, color='r')
#plt.plot(X2_plot, Y2_plot, color='g')

plt.show()

# %%
ax = sns.scatterplot(x='Scale', y='Value', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[(final_df['Type']=='GenBound')&(final_df['N']==6400)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot (N=6400)')
plt.yscale('log')

plt.xlabel('Scale')
plt.ylabel('Emperical Generalization Bound')

plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Scale', hue='N', palette='colorblind', sizes=(20, 200), data=final_df[final_df['Type']=='GenBound'])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Emperical Generalization Bound Plot')
plt.yscale('log')
plt.xscale('log')

plt.xlabel('M (Number of Nodes)')
plt.ylabel('Emperical Generalization Bound')
plt.show()

# %%
ax = sns.scatterplot(x='N', y='Value', style='Scale', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[final_df['Type']=='TrainTime'])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Train Time (Epochs) Plot')
plt.yscale('log')

plt.xlabel('N (Samples)')
plt.ylabel('Train Time (Epochs)')
plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Scale', hue='N', palette='colorblind', sizes=(20, 200), data=final_df[final_df['Type']=='TrainTime'])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines Train Time (Epochs) Plot')
plt.yscale('log')
plt.xscale('log')

plt.xlabel('M (Number of Nodes)')
plt.ylabel('Train Time (Epochs)')
plt.show()

# %%
final_df = final_df[final_df.Type != 'GenBound']
final_df = final_df[final_df.Type != 'GenErr']
final_df = final_df[final_df.Type != 'TrainTime']

# %%
ax = sns.scatterplot(x='N', y='M', style='Scale', hue='Type', size='Value', sizes=(20, 200), data=final_df)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
ax = sns.scatterplot(x='N', y='Scale', style='M', hue='Type', size='Value', sizes=(20, 200), data=final_df)
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', size='N',palette='colorblind', hue='Scale', sizes=(20, 200), data=final_df[(final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val')])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.title('Sum of Product of Sines Summary Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')
plt.xscale('log')

plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='Scale', palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.title('Sum of Product of Sines N=160 Plot')
plt.xlabel('M (Number of Nodes)')
plt.xscale('log')

plt.ylabel('Value of Loss')
plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='Scale', palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==1600)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=1600 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')
plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='Scale', palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==6400)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=6400 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

#X_plot = np.linspace(50, 500, 100)
#Y_plot = 1/(X_plot)

#plt.plot(X_plot, Y_plot, color='r')
plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='N', palette='colorblind', sizes=(20, 200), data=final_df[final_df['Scale']==1.0])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines s=1.0 Plot')
plt.yscale('log')
plt.xscale('log')

plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')
plt.show()

# %%
ax = sns.scatterplot(x='N', y='Value', style='Type', hue='M', palette='colorblind', sizes=(20, 200), data=final_df[final_df['Scale']==1.0])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('Sum of Product of Sines s=1.0 Plot')
plt.yscale('log')

plt.xlabel('N (Samples)')
plt.ylabel('Value of Loss')
plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='Scale', palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==6400)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=6400 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

X_plot = np.linspace(50, 500, 100)
XB_plot = np.linspace(200, 10000, 1000)
XBB_plot = np.linspace(500, 20000, 1000)

Y_plot = .3/(X_plot)
YBB_plot = .000001*(XBB_plot)


plt.plot(X_plot, Y_plot, color='r')
plt.plot(XBB_plot, YBB_plot, color='r')

Y2_plot = .03/(X_plot)
Y2B_plot = .0000003*(XB_plot)

plt.plot(X_plot, Y2_plot, color='b')
plt.plot(XB_plot, Y2B_plot, color='b')

Y3_plot = 1/(X_plot)
Y3BB_plot = .000004*(XBB_plot)

plt.plot(X_plot, Y3_plot, color='g')
plt.plot(XBB_plot, Y3BB_plot, color='g')

plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='Scale', hue_order=[0.5,1.0,1.5,2.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==1600)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=1600 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

X_plot = np.linspace(50, 500, 100)
Y_plot = .04/(X_plot)
X2_plot = np.linspace(50, 500, 100)
Y2_plot = 8/(X_plot)

plt.plot(X_plot, Y_plot, color='r')
plt.plot(X2_plot, Y2_plot, color='b')

plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='Scale', hue_order=[0.5,1.0,1.5,2.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=160 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

X_plot = np.linspace(50, 5000, 100)
Y_plot = 1/(X_plot)

plt.plot(X_plot, Y_plot, color='r')
plt.show()

# %%
ax = sns.scatterplot(x='M', y='Value', style='Type', hue='Scale', hue_order=[0.5,1.0,1.5,2.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==16000)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=16000 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')
# Out:
# Text(0, 0.5, 'Value of Loss')

# %%
ax = sns.lineplot(x='M', y='Value',markers=True , style='Scale', hue='Scale', hue_order=[0.5,1.0,1.5,2.0], style_order=[0.5,1.0,1.5,2.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=160 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

plt.show()

# %%
ax = sns.lineplot(x='M', y='Value',markers=True , style='Scale',hue='Scale', hue_order=[0.5,1.0,1.5,2.0], style_order=[0.5,1.0,1.5,2.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==1600)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=1600 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

plt.show()

# %%
ax = sns.lineplot(x='M', y='Value',markers=True , style='Scale',hue='Scale', hue_order=[0.5,1.0,1.5,2.0,2.5,3.0], style_order=[0.5,1.0,1.5,2.0,2.5,3.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==6400)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=6400 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

X_plot = np.linspace(50, 500, 100)
XB_plot = np.linspace(200, 10000, 1000)
XBB_plot = np.linspace(500, 20000, 1000)

Y_plot = .3/(X_plot)
YBB_plot = .000001*(XBB_plot)


plt.plot(X_plot, Y_plot, color='r')
plt.plot(XBB_plot, YBB_plot, color='r')

Y2_plot = .03/(X_plot)
Y2B_plot = .0000003*(XB_plot)

plt.plot(X_plot, Y2_plot, color='b')
plt.plot(XB_plot, Y2B_plot, color='b')

Y3_plot = 1/(X_plot)
Y3BB_plot = .000004*(XBB_plot)

plt.plot(X_plot, Y3_plot, color='g')
plt.plot(XBB_plot, Y3BB_plot, color='g')

plt.show()

# %%
ax = sns.lineplot(x='M', y='Value',markers=True , style='Scale',hue='Scale', palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==16000)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=16000 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')

plt.show()

# %%
ax = sns.lineplot(x='M', y='Value',markers=True , style='Scale',hue='Scale', hue_order=[0.5,1.0,1.5,2.0,2.5,3.0], style_order=[0.5,1.0,1.5,2.0,2.5,3.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines N=160 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')


plt.show()

# %%
ax = sns.lineplot(x='N', y='Value',markers=True , style='Scale',hue='Scale', hue_order=[0.5,1.0,1.5,2.0,2.5,3.0], style_order=[0.5,1.0,1.5,2.0,2.5,3.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['M']==2000)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.yscale('log')
plt.xscale('log')

plt.title('Sum of Product of Sines M=2000 Plot')
plt.xlabel('N (Number of Samples)')
plt.ylabel('Value of Loss')


plt.show()

# %%
ax = sns.lineplot(x='M', y='Value',markers=True , style='Scale',hue='Scale', hue_order=[0.5,1.0,1.5,2.0,2.5,3.0], style_order=[0.5,1.0,1.5,2.0,2.5,3.0], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['N']==160)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xscale('log')

plt.title('Sum of Product of Sines N=160 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')


plt.show()

# %%
ax = sns.lineplot(x='N', y='Value',markers=True , style='M',hue='M', hue_order=[50,100,200,500,1000,2000,5000,10000,20000], style_order=[50,100,200,500,1000,2000,5000,10000,20000], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['Scale']==3.0)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xscale('log')

plt.title('Sum of Product of Sines Scale=3.0 Plot')
plt.xlabel('N (Number of Samples)')
plt.ylabel('Value of Loss')


plt.show()

# %%
ax = sns.lineplot(x='N', y='Value',markers=True , style='M',hue='M', hue_order=[50,100,200,500,1000,2000,5000,10000,20000], style_order=[50,100,200,500,1000,2000,5000,10000,20000], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['Scale']==2.0)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xscale('log')

plt.title('Sum of Product of Sines Scale=2.0 Plot')
plt.xlabel('N (Number of Samples)')
plt.ylabel('Value of Loss')


plt.show()

# %%
ax = sns.lineplot(x='M', y='Value',markers=True , style='N',hue='N', hue_order=[160,1600,6400,16000], style_order=[160,1600,6400,16000], palette='colorblind', sizes=(20, 200), data=final_df[((final_df['Type']=='Max')|(final_df['Type']=='Train')|(final_df['Type']=='Val'))&(final_df['Scale']==3.0)])
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.xscale('log')
plt.yscale('log')

plt.title('Sum of Product of Sines Scale=3.0 Plot')
plt.xlabel('M (Number of Nodes)')
plt.ylabel('Value of Loss')


plt.show()
